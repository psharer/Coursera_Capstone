# %% [markdown]
# # New York Locating a New York Night Club

# %% [markdown]
# ## Install Dependencies

# %%
conda install geopandas #conda install --channel conda-forge geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\psharer\anaconda3\envs\Coursera
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cfitsio-3.470              |       he774522_6         512 KB
#     click-plugins-1.1.1        |             py_0          12 KB
#     cligj-0.7.1                |   py38haa95532_0          14 KB
#     curl-7.67.0                |       h2a8f88b_0         123 KB
#     expat-2.2.10               |       h33f27b4_2         187 KB
#     fiona-1.8.13.post1         |   py38hd760492_0         619 KB
#     freexl-1.0.6               |       h2bbff1b_0          51 KB
#     gdal-3.0.2                 |   py38hdf43c64_0         1.0 MB
#     geopandas-0.8.1            |             py_0         902 KB
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     geotiff-1.5.1              |       h5770a2b_1         126 KB
#     hdf4-4.2.13                |       h712560f_2         1.3 MB
#     kealib-1.4.7               |       h07cbb95_6         133 KB
#     krb5-1.16.4                |       hc04afaa_0         693 KB
#     libboost-1.67.0            |       hd9e427e_4        18.6 MB
#     libcurl-7.67.0             |       h2a8f88b_0         269 KB
#     libgdal-3.0.2              |       h1155b67_0         7.0 MB
#     libkml-1.3.0               |       he5f2a48_4        19.7 MB
#     libnetcdf-4.6.1            |       h411e497_2         494 KB
#     libpq-11.2                 |       h3235a2c_0         2.6 MB
#     libspatialite-4.3.0a       |       h7ffb84d_0         2.3 MB
#     libtiff-4.1.0              |       h56a325e_0         737 KB
#     lz4-c-1.8.1.2              |       h2fa13f4_0         176 KB
#     m2w64-expat-2.1.1          |                2         160 KB
#     m2w64-gettext-0.19.7       |                2         4.2 MB
#     m2w64-libiconv-1.14        |                6         1.5 MB
#     m2w64-xz-5.2.2             |                2         395 KB
#     mkl-service-2.3.0          |   py38h196d8e1_0          47 KB
#     munch-2.5.0                |             py_0          15 KB
#     openjpeg-2.3.0             |       h5ec785f_1         205 KB
#     pandas-1.2.0               |   py38hf11a4ad_0         7.9 MB
#     pcre-8.44                  |       ha925a31_0         384 KB
#     postgresql-11.2            |       h3235a2c_0        13.0 MB
#     proj-6.2.1                 |       h9f7ef89_0         7.9 MB
#     pyproj-2.6.1.post1         |   py38hcfa1391_1         320 KB
#     pytz-2020.5                |     pyhd3eb1b0_0         182 KB
#     shapely-1.7.1              |   py38h210f175_0         374 KB
#     tbb-2018.0.5               |       he980bc4_0         150 KB
#     tiledb-1.6.3               |       h7b000aa_0         1.3 MB
#     xerces-c-3.2.3             |       ha925a31_0         2.8 MB
#     zstd-1.3.7                 |       h508b16e_0         337 KB
#     ------------------------------------------------------------
#                                            Total:        99.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-he774522_0
#   cfitsio            pkgs/main/win-64::cfitsio-3.470-he774522_6
#   click              pkgs/main/noarch::click-7.1.2-py_0
#   click-plugins      pkgs/main/noarch::click-plugins-1.1.1-py_0
#   cligj              pkgs/main/win-64::cligj-0.7.1-py38haa95532_0
#   curl               pkgs/main/win-64::curl-7.67.0-h2a8f88b_0
#   expat              pkgs/main/win-64::expat-2.2.10-h33f27b4_2
#   fiona              pkgs/main/win-64::fiona-1.8.13.post1-py38hd760492_0
#   freexl             pkgs/main/win-64::freexl-1.0.6-h2bbff1b_0
#   gdal               pkgs/main/win-64::gdal-3.0.2-py38hdf43c64_0
#   geopandas          pkgs/main/noarch::geopandas-0.8.1-py_0
#   geos               pkgs/main/win-64::geos-3.8.0-h33f27b4_0
#   geotiff            pkgs/main/win-64::geotiff-1.5.1-h5770a2b_1
#   hdf4               pkgs/main/win-64::hdf4-4.2.13-h712560f_2
#   hdf5               pkgs/main/win-64::hdf5-1.10.4-h7ebc959_0
#   icc_rt             pkgs/main/win-64::icc_rt-2019.0.0-h0cc432a_1
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   intel-openmp       pkgs/main/win-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/win-64::jpeg-9b-hb83a4c4_2
#   kealib             pkgs/main/win-64::kealib-1.4.7-h07cbb95_6
#   krb5               pkgs/main/win-64::krb5-1.16.4-hc04afaa_0
#   libboost           pkgs/main/win-64::libboost-1.67.0-hd9e427e_4
#   libcurl            pkgs/main/win-64::libcurl-7.67.0-h2a8f88b_0
#   libgdal            pkgs/main/win-64::libgdal-3.0.2-h1155b67_0
#   libiconv           pkgs/main/win-64::libiconv-1.15-h1df5818_7
#   libkml             pkgs/main/win-64::libkml-1.3.0-he5f2a48_4
#   libnetcdf          pkgs/main/win-64::libnetcdf-4.6.1-h411e497_2
#   libpng             pkgs/main/win-64::libpng-1.6.37-h2a8f88b_0
#   libpq              pkgs/main/win-64::libpq-11.2-h3235a2c_0
#   libspatialindex    pkgs/main/win-64::libspatialindex-1.9.3-h33f27b4_0
#   libspatialite      pkgs/main/win-64::libspatialite-4.3.0a-h7ffb84d_0
#   libssh2            pkgs/main/win-64::libssh2-1.9.0-h7a1dbc1_1
#   libtiff            pkgs/main/win-64::libtiff-4.1.0-h56a325e_0
#   libxml2            pkgs/main/win-64::libxml2-2.9.10-hb89e7f3_3
#   lz4-c              pkgs/main/win-64::lz4-c-1.8.1.2-h2fa13f4_0
#   m2w64-expat        pkgs/msys2/win-64::m2w64-expat-2.1.1-2
#   m2w64-gettext      pkgs/msys2/win-64::m2w64-gettext-0.19.7-2
#   m2w64-libiconv     pkgs/msys2/win-64::m2w64-libiconv-1.14-6
#   m2w64-xz           pkgs/msys2/win-64::m2w64-xz-5.2.2-2
#   mkl                pkgs/main/win-64::mkl-2020.2-256
#   mkl-service        pkgs/main/win-64::mkl-service-2.3.0-py38h196d8e1_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.2.0-py38h45dec08_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.1.1-py38h47e9c7a_0
#   munch              pkgs/main/noarch::munch-2.5.0-py_0
#   numpy              pkgs/main/win-64::numpy-1.19.2-py38hadc3359_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.19.2-py38ha3acd2a_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.3.0-h5ec785f_1
#   pandas             pkgs/main/win-64::pandas-1.2.0-py38hf11a4ad_0
#   pcre               pkgs/main/win-64::pcre-8.44-ha925a31_0
#   postgresql         pkgs/main/win-64::postgresql-11.2-h3235a2c_0
#   proj               pkgs/main/win-64::proj-6.2.1-h9f7ef89_0
#   pyproj             pkgs/main/win-64::pyproj-2.6.1.post1-py38hcfa1391_1
#   pytz               pkgs/main/noarch::pytz-2020.5-pyhd3eb1b0_0
#   rtree              pkgs/main/win-64::rtree-0.9.4-py38h21ff451_1
#   shapely            pkgs/main/win-64::shapely-1.7.1-py38h210f175_0
#   tbb                pkgs/main/win-64::tbb-2018.0.5-he980bc4_0
#   tiledb             pkgs/main/win-64::tiledb-1.6.3-h7b000aa_0
#   tk                 pkgs/main/win-64::tk-8.6.10-he774522_0
#   xerces-c           pkgs/main/win-64::xerces-c-3.2.3-ha925a31_0
#   xz                 pkgs/main/win-64::xz-5.2.5-h62dcd97_0
#   zstd               pkgs/main/win-64::zstd-1.3.7-h508b16e_0
#
#
#
# Downloading and Extracting Packages
#
# click-plugins-1.1.1  | 12 KB     |            |   0%
# click-plugins-1.1.1  | 12 KB     | ########## | 100%
# click-plugins-1.1.1  | 12 KB     | ########## | 100%
#
# libnetcdf-4.6.1      | 494 KB    |            |   0%
# libnetcdf-4.6.1      | 494 KB    | ####8      |  49%
# libnetcdf-4.6.1      | 494 KB    | ########## | 100%
# libnetcdf-4.6.1      | 494 KB    | ########## | 100%
#
# xerces-c-3.2.3       | 2.8 MB    |            |   0%
# xerces-c-3.2.3       | 2.8 MB    | 8          |   9%
# xerces-c-3.2.3       | 2.8 MB    | ######5    |  66%
# xerces-c-3.2.3       | 2.8 MB    | ########## | 100%
# xerces-c-3.2.3       | 2.8 MB    | ########## | 100%
#
# kealib-1.4.7         | 133 KB    |            |   0%
# kealib-1.4.7         | 133 KB    | ########## | 100%
# kealib-1.4.7         | 133 KB    | ########## | 100%
#
# expat-2.2.10         | 187 KB    |            |   0%
# expat-2.2.10         | 187 KB    | ########## | 100%
# expat-2.2.10         | 187 KB    | ########## | 100%
#
# pytz-2020.5          | 182 KB    |            |   0%
# pytz-2020.5          | 182 KB    | ########## | 100%
# pytz-2020.5          | 182 KB    | ########## | 100%
#
# geotiff-1.5.1        | 126 KB    |            |   0%
# geotiff-1.5.1        | 126 KB    | #2         |  13%
# geotiff-1.5.1        | 126 KB    | ########## | 100%
# geotiff-1.5.1        | 126 KB    | ########## | 100%
#
# pandas-1.2.0         | 7.9 MB    |            |   0%
# pandas-1.2.0         | 7.9 MB    | 6          |   6%
# pandas-1.2.0         | 7.9 MB    | ##3        |  23%
# pandas-1.2.0         | 7.9 MB    | ####1      |  41%
# pandas-1.2.0         | 7.9 MB    | #####7     |  57%
# pandas-1.2.0         | 7.9 MB    | ########8  |  89%
# pandas-1.2.0         | 7.9 MB    | ########## | 100%
#
# libgdal-3.0.2        | 7.0 MB    |            |   0%
# libgdal-3.0.2        | 7.0 MB    |            |   0%
# libgdal-3.0.2        | 7.0 MB    | ##7        |  27%
# libgdal-3.0.2        | 7.0 MB    | ####9      |  50%
# libgdal-3.0.2        | 7.0 MB    | #######1   |  71%
# libgdal-3.0.2        | 7.0 MB    | #########2 |  93%
# libgdal-3.0.2        | 7.0 MB    | ########## | 100%
#
# postgresql-11.2      | 13.0 MB   |            |   0%
# postgresql-11.2      | 13.0 MB   | 4          |   4%
# postgresql-11.2      | 13.0 MB   | #6         |  16%
# postgresql-11.2      | 13.0 MB   | ##         |  21%
# postgresql-11.2      | 13.0 MB   | ###6       |  37%
# postgresql-11.2      | 13.0 MB   | ####6      |  46%
# postgresql-11.2      | 13.0 MB   | #####9     |  60%
# postgresql-11.2      | 13.0 MB   | #######2   |  73%
# postgresql-11.2      | 13.0 MB   | ########3  |  84%
# postgresql-11.2      | 13.0 MB   | #########5 |  96%
# postgresql-11.2      | 13.0 MB   | ########## | 100%
#
# curl-7.67.0          | 123 KB    |            |   0%
# curl-7.67.0          | 123 KB    | ########## | 100%
# curl-7.67.0          | 123 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 47 KB     |            |   0%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
#
# pyproj-2.6.1.post1   | 320 KB    |            |   0%
# pyproj-2.6.1.post1   | 320 KB    | 5          |   5%
# pyproj-2.6.1.post1   | 320 KB    | ########## | 100%
# pyproj-2.6.1.post1   | 320 KB    | ########## | 100%
#
# freexl-1.0.6         | 51 KB     |            |   0%
# freexl-1.0.6         | 51 KB     | ########## | 100%
# freexl-1.0.6         | 51 KB     | ########## | 100%
#
# hdf4-4.2.13          | 1.3 MB    |            |   0%
# hdf4-4.2.13          | 1.3 MB    | ##         |  21%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
# hdf4-4.2.13          | 1.3 MB    | ########## | 100%
#
# proj-6.2.1           | 7.9 MB    |            |   0%
# proj-6.2.1           | 7.9 MB    | 5          |   6%
# proj-6.2.1           | 7.9 MB    | #7         |  18%
# proj-6.2.1           | 7.9 MB    | ##8        |  29%
# proj-6.2.1           | 7.9 MB    | #####3     |  54%
# proj-6.2.1           | 7.9 MB    | ######4    |  65%
# proj-6.2.1           | 7.9 MB    | #######9   |  80%
# proj-6.2.1           | 7.9 MB    | ########## | 100%
# proj-6.2.1           | 7.9 MB    | ########## | 100%
#
# fiona-1.8.13.post1   | 619 KB    |            |   0%
# fiona-1.8.13.post1   | 619 KB    | ######4    |  65%
# fiona-1.8.13.post1   | 619 KB    | ########## | 100%
# fiona-1.8.13.post1   | 619 KB    | ########## | 100%
#
# cfitsio-3.470        | 512 KB    |            |   0%
# cfitsio-3.470        | 512 KB    | #########6 |  97%
# cfitsio-3.470        | 512 KB    | ########## | 100%
#
# krb5-1.16.4          | 693 KB    |            |   0%
# krb5-1.16.4          | 693 KB    | #########4 |  95%
# krb5-1.16.4          | 693 KB    | ########## | 100%
#
# lz4-c-1.8.1.2        | 176 KB    |            |   0%
# lz4-c-1.8.1.2        | 176 KB    | ########## | 100%
# lz4-c-1.8.1.2        | 176 KB    | ########## | 100%
#
# libboost-1.67.0      | 18.6 MB   |            |   0%
# libboost-1.67.0      | 18.6 MB   | 3          |   3%
# libboost-1.67.0      | 18.6 MB   | 5          |   5%
# libboost-1.67.0      | 18.6 MB   | 9          |  10%
# libboost-1.67.0      | 18.6 MB   | #7         |  17%
# libboost-1.67.0      | 18.6 MB   | ##5        |  25%
# libboost-1.67.0      | 18.6 MB   | ###2       |  33%
# libboost-1.67.0      | 18.6 MB   | ####       |  41%
# libboost-1.67.0      | 18.6 MB   | ####8      |  48%
# libboost-1.67.0      | 18.6 MB   | #####4     |  55%
# libboost-1.67.0      | 18.6 MB   | ########## | 100%
# libboost-1.67.0      | 18.6 MB   | ########## | 100%
#
# pcre-8.44            | 384 KB    |            |   0%
# pcre-8.44            | 384 KB    | #2         |  13%
# pcre-8.44            | 384 KB    | ########## | 100%
# pcre-8.44            | 384 KB    | ########## | 100%
#
# m2w64-gettext-0.19.7 | 4.2 MB    |            |   0%
# m2w64-gettext-0.19.7 | 4.2 MB    | ##4        |  24%
# m2w64-gettext-0.19.7 | 4.2 MB    | #####5     |  55%
# m2w64-gettext-0.19.7 | 4.2 MB    | ########1  |  81%
# m2w64-gettext-0.19.7 | 4.2 MB    | ########## | 100%
# m2w64-gettext-0.19.7 | 4.2 MB    | ########## | 100%
#
# cligj-0.7.1          | 14 KB     |            |   0%
# cligj-0.7.1          | 14 KB     | ########## | 100%
# cligj-0.7.1          | 14 KB     | ########## | 100%
#
# m2w64-xz-5.2.2       | 395 KB    |            |   0%
# m2w64-xz-5.2.2       | 395 KB    | ########## | 100%
# m2w64-xz-5.2.2       | 395 KB    | ########## | 100%
#
# libkml-1.3.0         | 19.7 MB   |            |   0%
# libkml-1.3.0         | 19.7 MB   | 1          |   1%
# libkml-1.3.0         | 19.7 MB   | 7          |   7%
# libkml-1.3.0         | 19.7 MB   | #4         |  15%
# libkml-1.3.0         | 19.7 MB   | ##3        |  23%
# libkml-1.3.0         | 19.7 MB   | ###        |  31%
# libkml-1.3.0         | 19.7 MB   | ###6       |  36%
# libkml-1.3.0         | 19.7 MB   | ####6      |  46%
# libkml-1.3.0         | 19.7 MB   | #####4     |  55%
# libkml-1.3.0         | 19.7 MB   | ######1    |  62%
# libkml-1.3.0         | 19.7 MB   | ######9    |  69%
# libkml-1.3.0         | 19.7 MB   | #######6   |  77%
# libkml-1.3.0         | 19.7 MB   | ########4  |  84%
# libkml-1.3.0         | 19.7 MB   | #########9 | 100%
# libkml-1.3.0         | 19.7 MB   | ########## | 100%
#
# libcurl-7.67.0       | 269 KB    |            |   0%
# libcurl-7.67.0       | 269 KB    | ########## | 100%
# libcurl-7.67.0       | 269 KB    | ########## | 100%
#
# libpq-11.2           | 2.6 MB    |            |   0%
# libpq-11.2           | 2.6 MB    | #4         |  15%
# libpq-11.2           | 2.6 MB    | #####7     |  57%
# libpq-11.2           | 2.6 MB    | ########## | 100%
# libpq-11.2           | 2.6 MB    | ########## | 100%
#
# tbb-2018.0.5         | 150 KB    |            |   0%
# tbb-2018.0.5         | 150 KB    | ########## | 100%
# tbb-2018.0.5         | 150 KB    | ########## | 100%
#
# shapely-1.7.1        | 374 KB    |            |   0%
# shapely-1.7.1        | 374 KB    | ########## | 100%
# shapely-1.7.1        | 374 KB    | ########## | 100%
#
# gdal-3.0.2           | 1.0 MB    |            |   0%
# gdal-3.0.2           | 1.0 MB    | ####4      |  44%
# gdal-3.0.2           | 1.0 MB    | ########## | 100%
# gdal-3.0.2           | 1.0 MB    | ########## | 100%
#
# libspatialite-4.3.0a | 2.3 MB    |            |   0%
# libspatialite-4.3.0a | 2.3 MB    |            |   1%
# libspatialite-4.3.0a | 2.3 MB    | ########## | 100%
# libspatialite-4.3.0a | 2.3 MB    | ########## | 100%
#
# munch-2.5.0          | 15 KB     |            |   0%
# munch-2.5.0          | 15 KB     | ########## | 100%
# munch-2.5.0          | 15 KB     | ########## | 100%
#
# m2w64-libiconv-1.14  | 1.5 MB    |            |   0%
# m2w64-libiconv-1.14  | 1.5 MB    | ####2      |  43%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
#
# zstd-1.3.7           | 337 KB    |            |   0%
# zstd-1.3.7           | 337 KB    | ########## | 100%
# zstd-1.3.7           | 337 KB    | ########## | 100%
#
# openjpeg-2.3.0       | 205 KB    |            |   0%
# openjpeg-2.3.0       | 205 KB    | ########## | 100%
# openjpeg-2.3.0       | 205 KB    | ########## | 100%
#
# tiledb-1.6.3         | 1.3 MB    |            |   0%
# tiledb-1.6.3         | 1.3 MB    | #####6     |  56%
# tiledb-1.6.3         | 1.3 MB    | ########## | 100%
# tiledb-1.6.3         | 1.3 MB    | ########## | 100%
#
# m2w64-expat-2.1.1    | 160 KB    |            |   0%
# m2w64-expat-2.1.1    | 160 KB    | ########## | 100%
# m2w64-expat-2.1.1    | 160 KB    | ########## | 100%
#
# geos-3.8.0           | 905 KB    |            |   0%
# geos-3.8.0           | 905 KB    | #######4   |  74%
# geos-3.8.0           | 905 KB    | ########## | 100%
# geos-3.8.0           | 905 KB    | ########## | 100%
#
# geopandas-0.8.1      | 902 KB    |            |   0%
# geopandas-0.8.1      | 902 KB    | 5          |   5%
# geopandas-0.8.1      | 902 KB    | ########## | 100%
# geopandas-0.8.1      | 902 KB    | ########## | 100%
#
# libtiff-4.1.0        | 737 KB    |            |   0%
# libtiff-4.1.0        | 737 KB    | ######7    |  67%
# libtiff-4.1.0        | 737 KB    | ########## | 100%
# libtiff-4.1.0        | 737 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\psharer\anaconda3\envs\Coursera
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       h5b45459_0         173 KB  conda-forge
#     certifi-2020.12.5          |   py38haa244fe_1         144 KB  conda-forge
#     openssl-1.1.1i             |       h8ffe710_0         5.8 MB  conda-forge
#
#     ------------------------------------------------------------
#                                            Total:         6.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.1.0-pyhd3deb0d_0
#   python_abi         conda-forge/win-64::python_abi-3.8-1_cp38
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2020.12.5-py38haa9~ --> conda-forge::certifi-2020.12.5-py38haa244fe_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2020.12.8-~ --> conda-forge::ca-certificates-2020.12.5-h5b45459_0
#   openssl              pkgs/main::openssl-1.1.1i-h2bbff1b_0 --> conda-forge::openssl-1.1.1i-h8ffe710_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2020.12.5    | 144 KB    |            |   0%
# certifi-2020.12.5    | 144 KB    | #1         |  11%
# certifi-2020.12.5    | 144 KB    | ########## | 100%
# certifi-2020.12.5    | 144 KB    | ########## | 100%
#
# openssl-1.1.1i       | 5.8 MB    |            |   0%
# openssl-1.1.1i       | 5.8 MB    | 4          |   5%
# openssl-1.1.1i       | 5.8 MB    | #5         |  16%
# openssl-1.1.1i       | 5.8 MB    | ###4       |  34%
# openssl-1.1.1i       | 5.8 MB    | ######     |  60%
# openssl-1.1.1i       | 5.8 MB    | #######9   |  80%
# openssl-1.1.1i       | 5.8 MB    | ########## | 100%
# openssl-1.1.1i       | 5.8 MB    | ########## | 100%
#
# ca-certificates-2020 | 173 KB    |            |   0%
# ca-certificates-2020 | 173 KB    | 9          |   9%
# ca-certificates-2020 | 173 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\psharer\anaconda3\envs\Coursera
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.2               |     pyhd8ed1ab_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py38hab1e662_1001         368 KB  conda-forge
#     chardet-4.0.0              |   py38haa244fe_1         224 KB  conda-forge
#     cryptography-3.3.1         |   py38hd8c33c5_0         596 KB  conda-forge
#     folium-0.12.0              |     pyhd8ed1ab_0          64 KB  conda-forge
#     idna-2.10                  |     pyh9f0ad1d_0          52 KB  conda-forge
#     pyopenssl-20.0.1           |     pyhd8ed1ab_0          48 KB  conda-forge
#     pysocks-1.7.1              |   py38haa244fe_3          28 KB  conda-forge
#     requests-2.25.1            |     pyhd3deb0d_0          51 KB  conda-forge
#     urllib3-1.26.2             |     pyhd8ed1ab_0          98 KB  conda-forge
#     win_inet_pton-1.1.0        |   py38haa244fe_2           8 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   branca             conda-forge/noarch::branca-0.4.2-pyhd8ed1ab_0
#   brotlipy           conda-forge/win-64::brotlipy-0.7.0-py38hab1e662_1001
#   chardet            conda-forge/win-64::chardet-4.0.0-py38haa244fe_1
#   cryptography       conda-forge/win-64::cryptography-3.3.1-py38hd8c33c5_0
#   folium             conda-forge/noarch::folium-0.12.0-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   pyopenssl          conda-forge/noarch::pyopenssl-20.0.1-pyhd8ed1ab_0
#   pysocks            conda-forge/win-64::pysocks-1.7.1-py38haa244fe_3
#   requests           conda-forge/noarch::requests-2.25.1-pyhd3deb0d_0
#   urllib3            conda-forge/noarch::urllib3-1.26.2-pyhd8ed1ab_0
#   win_inet_pton      conda-forge/win-64::win_inet_pton-1.1.0-py38haa244fe_2
#
#
#
# Downloading and Extracting Packages
#
# idna-2.10            | 52 KB     |            |   0%
# idna-2.10            | 52 KB     | ###        |  31%
# idna-2.10            | 52 KB     | ########## | 100%
#
# win_inet_pton-1.1.0  | 8 KB      |            |   0%
# win_inet_pton-1.1.0  | 8 KB      | ########## | 100%
# win_inet_pton-1.1.0  | 8 KB      | ########## | 100%
#
# cryptography-3.3.1   | 596 KB    |            |   0%
# cryptography-3.3.1   | 596 KB    | 2          |   3%
# cryptography-3.3.1   | 596 KB    | ########## | 100%
# cryptography-3.3.1   | 596 KB    | ########## | 100%
#
# pysocks-1.7.1        | 28 KB     |            |   0%
# pysocks-1.7.1        | 28 KB     | ########## | 100%
# pysocks-1.7.1        | 28 KB     | ########## | 100%
#
# pyopenssl-20.0.1     | 48 KB     |            |   0%
# pyopenssl-20.0.1     | 48 KB     | ###3       |  34%
# pyopenssl-20.0.1     | 48 KB     | ########## | 100%
# pyopenssl-20.0.1     | 48 KB     | ########## | 100%
#
# urllib3-1.26.2       | 98 KB     |            |   0%
# urllib3-1.26.2       | 98 KB     | ########## | 100%
# urllib3-1.26.2       | 98 KB     | ########## | 100%
#
# brotlipy-0.7.0       | 368 KB    |            |   0%
# brotlipy-0.7.0       | 368 KB    | ######9    |  70%
# brotlipy-0.7.0       | 368 KB    | ########## | 100%
#
# folium-0.12.0        | 64 KB     |            |   0%
# folium-0.12.0        | 64 KB     | ########## | 100%
# folium-0.12.0        | 64 KB     | ########## | 100%
#
#
# branca-0.4.2         | 26 KB     |            |   0%
# branca-0.4.2         | 26 KB     | ########## | 100%
#
# chardet-4.0.0        | 224 KB    |            |   0%
# chardet-4.0.0        | 224 KB    | 7          |   7%
# chardet-4.0.0        | 224 KB    | ########## | 100%
# chardet-4.0.0        | 224 KB    | ########## | 100%
#
# requests-2.25.1      | 51 KB     |            |   0%
# requests-2.25.1      | 51 KB     | ########## | 100%
# requests-2.25.1      | 51 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import folium # map rendering library
import requests
import numpy as np
import random
import json
import pandas as pd
from pandas import json_normalize

# %%
from geopy.geocoders import Nominatim

# %%
import geopandas as gpd
from shapely.geometry import Polygon
from shapely.geometry import Point

# %% [markdown]
# ## Defining Functions

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def get_venues_dataframe(lat,lon,radius,search_query,neighborhood):
    CLIENT_ID = 'ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420' # your Foursquare ID
    CLIENT_SECRET = 'IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA' # your Foursquare Secret
    VERSION = '20180604'
    LIMIT = 30
    print('Your credentails:')
    print('CLIENT_ID: ' + CLIENT_ID)
    print('CLIENT_SECRET:' + CLIENT_SECRET)
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]
    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
    # clean column names by keeping only last term
    dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
    dataframe_filtered['neighborhood'] = neighborhood;
    cols = dataframe_filtered.columns.tolist()
    cols = [cols[0],cols[len(cols)-1]]+cols[1:len(cols)-2]
    print(cols)
    dataframe_filtered = dataframe_filtered[cols];
    return dataframe_filtered

# %% [markdown]
# ## Data

# %%
nyc_geo = r'nyc-neighborhoods.geo.json' # geojson file
with open('.\\data\\nyc-neighborhoods.geo.json') as json_nyc_data:
    nyc_as_json = json.load(json_nyc_data)
nyc_as_json
df_nyc = pd.DataFrame(columns=["Name","Total"])
df_nyc.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-c5c56765ffe9> in <module>
#       1 nyc_geo = r'nyc-neighborhoods.geo.json' # geojson file
# ----> 2 with open('.\\data\\nyc-neighborhoods.geo.json') as json_nyc_data:
#       3     nyc_as_json = json.load(json_nyc_data)
#       4 nyc_as_json
#       5 df_nyc = pd.DataFrame(columns=["Name","Total"])
#
# FileNotFoundError: [Errno 2] No such file or directory: '.\\data\\nyc-neighborhoods.geo.json'

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Load Neighborhood geo data

# %% [markdown]
# ## Get the club data from Foursquare

# %% [markdown]
# ## Bin the clubs in the neighborhoods
