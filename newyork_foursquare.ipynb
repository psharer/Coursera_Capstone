# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install geopandas
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
from shapely.geometry import Polygon
from shapely.geometry import Point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-3e924e122578> in <module>
# ----> 1 import geopandas as gpd
#       2 from shapely.geometry import Polygon
#       3 from shapely.geometry import Point
#
# ModuleNotFoundError: No module named 'geopandas'
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining pytest:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining wcwidth:   0%|          | 1/316 [00:02<14:48,  2.82s/it]
# Examining wcwidth:   1%|          | 2/316 [00:02<07:23,  1.41s/it]
# Examining ipywidgets:   1%|          | 2/316 [00:02<07:23,  1.41s/it]
# Examining msgpack-python:   1%|          | 3/316 [00:04<07:21,  1.41s/it]
# Examining msgpack-python:   1%|1         | 4/316 [00:04<06:13,  1.20s/it]
# Examining bzip2:   1%|1         | 4/316 [00:04<06:13,  1.20s/it]
# Examining jedi:   2%|1         | 5/316 [00:04<06:12,  1.20s/it]
# Examining _ipyw_jlab_nb_ext_conf:   2%|1         | 6/316 [00:04<06:11,  1.20s/it]
# Examining _ipyw_jlab_nb_ext_conf:   2%|2         | 7/316 [00:04<04:24,  1.17it/s]
# Examining pathtools:   2%|2         | 7/316 [00:04<04:24,  1.17it/s]
# Examining pathtools:   3%|2         | 8/316 [00:04<03:19,  1.55it/s]
# Examining xlwt:   3%|2         | 8/316 [00:04<03:19,  1.55it/s]
# Examining webencodings:   3%|2         | 9/316 [00:04<03:18,  1.55it/s]
# Examining zeromq:   3%|3         | 10/316 [00:04<03:17,  1.55it/s]
# Examining sortedcollections:   3%|3         | 11/316 [00:04<03:17,  1.55it/s]
# Examining sympy:   4%|3         | 12/316 [00:04<03:16,  1.55it/s]
# Examining branca:   4%|4         | 13/316 [00:04<03:15,  1.55it/s]
# Examining branca:   4%|4         | 14/316 [00:04<02:21,  2.14it/s]
# Examining asn1crypto:   4%|4         | 14/316 [00:04<02:21,  2.14it/s]
# Examining urllib3:   5%|4         | 15/316 [00:04<02:20,  2.14it/s]
# Examining patsy:   5%|5         | 16/316 [00:05<02:20,  2.14it/s]
# Examining patsy:   5%|5         | 17/316 [00:05<02:07,  2.35it/s]
# Examining pywavelets:   5%|5         | 17/316 [00:06<02:07,  2.35it/s]
# Examining pywavelets:   6%|5         | 18/316 [00:06<02:04,  2.39it/s]
# Examining python-jsonrpc-server:   6%|5         | 18/316 [00:06<02:04,  2.39it/s]
# Examining python-jsonrpc-server:   6%|6         | 19/316 [00:06<02:24,  2.06it/s]
# Examining idna:   6%|6         | 19/316 [00:06<02:24,  2.06it/s]
# Examining beautifulsoup4:   6%|6         | 20/316 [00:06<02:23,  2.06it/s]
# Examining sphinxcontrib-serializinghtml:   7%|6         | 21/316 [00:07<02:23,  2.06it/s]
# Examining sphinxcontrib-serializinghtml:   7%|6         | 22/316 [00:07<01:44,  2.83it/s]
# Examining more-itertools:   7%|6         | 22/316 [00:07<01:44,  2.83it/s]
# Examining unicodecsv:   7%|7         | 23/316 [00:07<01:43,  2.83it/s]
# Examining mock:   8%|7         | 24/316 [00:07<01:43,  2.83it/s]
# Examining conda-build:   8%|7         | 25/316 [00:07<01:42,  2.83it/s]
# Examining conda-build:   8%|8         | 26/316 [00:07<01:14,  3.89it/s]
# Examining m2w64-gcc-libs-core:   8%|8         | 26/316 [00:17<01:14,  3.89it/s]
# Examining freetype:   9%|8         | 27/316 [00:17<01:14,  3.89it/s]
# Examining freetype:   9%|8         | 28/316 [00:17<08:36,  1.79s/it]
# Examining traitlets:   9%|8         | 28/316 [00:17<08:36,  1.79s/it]
# Examining sphinxcontrib-htmlhelp:   9%|9         | 29/316 [00:17<08:34,  1.79s/it]
# Examining wheel:   9%|9         | 30/316 [00:17<08:32,  1.79s/it]
# Examining icc_rt:  10%|9         | 31/316 [00:18<08:30,  1.79s/it]
# Examining icc_rt:  10%|#         | 32/316 [00:18<06:09,  1.30s/it]
# Examining libssh2:  10%|#         | 32/316 [00:18<06:09,  1.30s/it]
# Examining menuinst:  10%|#         | 33/316 [00:18<06:08,  1.30s/it]
# Examining html5lib:  11%|#         | 34/316 [00:18<06:07,  1.30s/it]
# Examining html5lib:  11%|#1        | 35/316 [00:18<04:19,  1.08it/s]
# Examining pyopenssl:  11%|#1        | 35/316 [00:18<04:19,  1.08it/s]
# Examining spyder:  11%|#1        | 36/316 [00:19<04:18,  1.08it/s]
# Examining spyder:  12%|#1        | 37/316 [00:19<03:15,  1.42it/s]
# Examining ipykernel:  12%|#1        | 37/316 [00:23<03:15,  1.42it/s]
# Examining ipykernel:  12%|#2        | 38/316 [00:23<08:57,  1.93s/it]
# Examining backports.functools_lru_cache:  12%|#2        | 38/316 [00:25<08:57,  1.93s/it]
# Examining backports.functools_lru_cache:  12%|#2        | 39/316 [00:25<08:05,  1.75s/it]
# Examining pycurl:  12%|#2        | 39/316 [00:25<08:05,  1.75s/it]
# Examining heapdict:  13%|#2        | 40/316 [00:25<08:03,  1.75s/it]
# Examining heapdict:  13%|#2        | 41/316 [00:25<05:44,  1.25s/it]
# Examining pywin32:  13%|#2        | 41/316 [00:25<05:44,  1.25s/it]
# Examining pytz:  13%|#3        | 42/316 [00:25<05:42,  1.25s/it]
# Examining ca-certificates:  14%|#3        | 43/316 [00:25<05:41,  1.25s/it]
# Examining ca-certificates:  14%|#3        | 44/316 [00:25<04:01,  1.13it/s]
# Examining bcrypt:  14%|#3        | 44/316 [00:25<04:01,  1.13it/s]
# Examining sphinxcontrib-devhelp:  14%|#4        | 45/316 [00:25<04:00,  1.13it/s]
# Examining sphinxcontrib-devhelp:  15%|#4        | 46/316 [00:25<02:55,  1.54it/s]
# Examining pandocfilters:  15%|#4        | 46/316 [00:25<02:55,  1.54it/s]
# Examining testpath:  15%|#4        | 47/316 [00:25<02:54,  1.54it/s]
# Examining werkzeug:  15%|#5        | 48/316 [00:25<02:53,  1.54it/s]
# Examining cython:  16%|#5        | 49/316 [00:25<02:53,  1.54it/s]
# Examining setuptools:  16%|#5        | 50/316 [00:26<02:52,  1.54it/s]
# Examining setuptools:  16%|#6        | 51/316 [00:26<02:19,  1.90it/s]
# Examining packaging:  16%|#6        | 51/316 [00:27<02:19,  1.90it/s]
# Examining packaging:  16%|#6        | 52/316 [00:27<02:16,  1.93it/s]
# Examining regex:  16%|#6        | 52/316 [00:27<02:16,  1.93it/s]
# Examining libarchive:  17%|#6        | 53/316 [00:27<02:15,  1.93it/s]
# Examining libarchive:  17%|#7        | 54/316 [00:27<01:43,  2.53it/s]
# Examining pluggy:  17%|#7        | 54/316 [00:27<01:43,  2.53it/s]
# Examining seaborn:  17%|#7        | 55/316 [00:27<01:43,  2.53it/s]
# Examining seaborn:  18%|#7        | 56/316 [00:27<01:16,  3.42it/s]
# Examining @/win-64::__win==0=0:  18%|#7        | 56/316 [00:28<01:16,  3.42it/s]
# Examining @/win-64::__archspec==1=x86_64:  18%|#8        | 57/316 [00:28<01:15,  3.42it/s]
# Examining @/win-64::__archspec==1=x86_64:  18%|#8        | 58/316 [00:28<01:36,  2.68it/s]
# Examining wincertstore:  18%|#8        | 58/316 [00:28<01:36,  2.68it/s]
# Examining jdcal:  19%|#8        | 59/316 [00:28<01:36,  2.68it/s]
# Examining scikit-image:  19%|#8        | 60/316 [00:28<01:35,  2.68it/s]
# Examining pep8:  19%|#9        | 61/316 [00:30<01:35,  2.68it/s]
# Examining pep8:  20%|#9        | 62/316 [00:30<01:44,  2.42it/s]
# Examining path:  20%|#9        | 62/316 [00:30<01:44,  2.42it/s]
# Examining snowballstemmer:  20%|#9        | 63/316 [00:30<01:44,  2.42it/s]
# Examining win_inet_pton:  20%|##        | 64/316 [00:30<01:44,  2.42it/s]
# Examining numpy-base:  21%|##        | 65/316 [00:30<01:43,  2.42it/s]
# Examining xmltodict:  21%|##        | 66/316 [00:31<01:43,  2.42it/s]
# Examining xmltodict:  21%|##1       | 67/316 [00:31<01:20,  3.08it/s]
# Examining entrypoints:  21%|##1       | 67/316 [00:31<01:20,  3.08it/s]
# Examining boto:  22%|##1       | 68/316 [00:31<01:20,  3.08it/s]
# Examining mkl_random:  22%|##1       | 69/316 [00:31<01:20,  3.08it/s]
# Examining openssl:  22%|##2       | 70/316 [00:31<01:19,  3.08it/s]
# Examining openssl:  22%|##2       | 71/316 [00:31<01:04,  3.80it/s]
# Examining cytoolz:  22%|##2       | 71/316 [00:31<01:04,  3.80it/s]
# Examining backports.tempfile:  23%|##2       | 72/316 [00:31<01:04,  3.80it/s]
# Examining cffi:  23%|##3       | 73/316 [00:31<01:03,  3.80it/s]
# Examining dask:  23%|##3       | 74/316 [00:32<01:03,  3.80it/s]
# Examining dask:  24%|##3       | 75/316 [00:32<00:47,  5.07it/s]
# Examining mccabe:  24%|##3       | 75/316 [00:43<00:47,  5.07it/s]
# Examining joblib:  24%|##4       | 76/316 [00:43<00:47,  5.07it/s]
# Examining joblib:  24%|##4       | 77/316 [00:43<07:41,  1.93s/it]
# Examining jupyter:  24%|##4       | 77/316 [00:44<07:41,  1.93s/it]
# Examining jupyter:  25%|##4       | 78/316 [00:44<05:32,  1.40s/it]
# Examining mkl_fft:  25%|##4       | 78/316 [00:45<05:32,  1.40s/it]
# Examining mkl_fft:  25%|##5       | 79/316 [00:45<05:23,  1.37s/it]
# Examining pandas:  25%|##5       | 79/316 [00:46<05:23,  1.37s/it]
# Examining pandas:  25%|##5       | 80/316 [00:46<05:17,  1.35s/it]
# Examining bleach:  25%|##5       | 80/316 [00:48<05:17,  1.35s/it]
# Examining bleach:  26%|##5       | 81/316 [00:48<06:01,  1.54s/it]
# Examining jupyter_client:  26%|##5       | 81/316 [00:49<06:01,  1.54s/it]
# Examining jupyter_client:  26%|##5       | 82/316 [00:49<04:41,  1.20s/it]
# Examining msys2-conda-epoch:  26%|##5       | 82/316 [00:49<04:41,  1.20s/it]
# Examining msys2-conda-epoch:  26%|##6       | 83/316 [00:49<03:44,  1.04it/s]
# Examining astropy:  26%|##6       | 83/316 [00:49<03:44,  1.04it/s]
# Examining greenlet:  27%|##6       | 84/316 [00:53<03:43,  1.04it/s]
# Examining greenlet:  27%|##6       | 85/316 [00:53<04:57,  1.29s/it]
# Examining numba:  27%|##6       | 85/316 [00:53<04:57,  1.29s/it]
# Examining jinja2:  27%|##7       | 86/316 [00:55<04:56,  1.29s/it]
# Examining jinja2:  28%|##7       | 87/316 [00:55<04:33,  1.19s/it]
# Examining conda-package-handling:  28%|##7       | 87/316 [00:55<04:33,  1.19s/it]
# Examining conda-package-handling:  28%|##7       | 88/316 [00:55<03:25,  1.11it/s]
# Examining curl:  28%|##7       | 88/316 [00:56<03:25,  1.11it/s]
# Examining curl:  28%|##8       | 89/316 [00:56<02:41,  1.40it/s]
# Examining python_abi:  28%|##8       | 89/316 [00:56<02:41,  1.40it/s]
# Examining toolz:  28%|##8       | 90/316 [00:56<02:41,  1.40it/s]
# Examining nltk:  29%|##8       | 91/316 [00:56<02:40,  1.40it/s]
# Examining sqlite:  29%|##9       | 92/316 [00:56<02:39,  1.40it/s]
# Examining sqlite:  29%|##9       | 93/316 [00:56<01:56,  1.92it/s]
# Examining mistune:  29%|##9       | 93/316 [00:56<01:56,  1.92it/s]
# Examining partd:  30%|##9       | 94/316 [00:56<01:55,  1.92it/s]
# Examining itsdangerous:  30%|###       | 95/316 [00:56<01:55,  1.92it/s]
# Examining docutils:  30%|###       | 96/316 [00:56<01:54,  1.92it/s]
# Examining fsspec:  31%|###       | 97/316 [00:56<01:54,  1.92it/s]
# Examining fsspec:  31%|###1      | 98/316 [00:56<01:20,  2.69it/s]
# Examining imageio:  31%|###1      | 98/316 [00:56<01:20,  2.69it/s]
# Examining pycodestyle:  31%|###1      | 99/316 [00:57<01:20,  2.69it/s]
# Examining pycodestyle:  32%|###1      | 100/316 [00:57<01:25,  2.52it/s]
# Examining toml:  32%|###1      | 100/316 [00:57<01:25,  2.52it/s]
# Examining psutil:  32%|###1      | 101/316 [00:57<01:25,  2.52it/s]
# Examining filelock:  32%|###2      | 102/316 [00:57<01:25,  2.52it/s]
# Examining filelock:  33%|###2      | 103/316 [00:57<01:01,  3.44it/s]
# Examining sphinxcontrib-applehelp:  33%|###2      | 103/316 [00:57<01:01,  3.44it/s]
# Examining babel:  92%|#########2| 292/316 [01:45<00:04,  5.05it/s]
# Examining @/win-64::__cuda==11.1=0:  93%|#########2| 293/316 [01:45<00:04,  5.05it/s]
# Examining @/win-64::__cuda==11.1=0:  93%|#########3| 294/316 [01:45<00:03,  6.87it/s]
# Examining scikit-learn:  93%|#########3| 294/316 [01:45<00:03,  6.87it/s]
# Examining pyparsing:  93%|#########3| 295/316 [01:46<00:03,  6.87it/s]
# Examining fastcache:  94%|#########3| 296/316 [01:47<00:02,  6.87it/s]
# Examining fastcache:  94%|#########3| 297/316 [01:47<00:05,  3.59it/s]
# Examining conda-env:  94%|#########3| 297/316 [01:47<00:05,  3.59it/s]
# Examining folium:  94%|#########4| 298/316 [01:47<00:05,  3.59it/s]
# Examining jupyterlab_server:  95%|#########4| 299/316 [01:47<00:04,  3.59it/s]
# Examining pyqt:  95%|#########4| 300/316 [01:47<00:04,  3.59it/s]
# Examining pyqt:  95%|#########5| 301/316 [01:47<00:03,  4.21it/s]
# Examining icu:  95%|#########5| 301/316 [01:47<00:03,  4.21it/s]
# Examining tqdm:  96%|#########5| 302/316 [01:47<00:03,  4.21it/s]
# Examining clyent:  96%|#########5| 303/316 [01:47<00:03,  4.21it/s]
# Examining clyent:  96%|#########6| 304/316 [01:47<00:02,  5.27it/s]
# Examining mkl-service:  96%|#########6| 304/316 [01:47<00:02,  5.27it/s]
# Examining libtiff:  97%|#########6| 305/316 [01:48<00:02,  5.27it/s]
# Examining libtiff:  97%|#########6| 306/316 [01:48<00:01,  6.03it/s]
# Examining geopy:  97%|#########6| 306/316 [01:48<00:01,  6.03it/s]
# Examining keyring:  97%|#########7| 307/316 [01:48<00:01,  6.03it/s]
# Examining pylint:  97%|#########7| 308/316 [01:48<00:01,  6.03it/s]
# Examining pylint:  98%|#########7| 309/316 [01:48<00:00,  7.01it/s]
# Examining pytables:  98%|#########7| 309/316 [01:48<00:00,  7.01it/s]
# Examining pywinpty:  98%|#########8| 310/316 [01:50<00:00,  7.01it/s]
# Examining pywinpty:  98%|#########8| 311/316 [01:50<00:01,  2.63it/s]
# Examining zope.event:  98%|#########8| 311/316 [01:50<00:01,  2.63it/s]
# Examining hdf5:  99%|#########8| 312/316 [01:50<00:01,  2.63it/s]
# Examining hdf5:  99%|#########9| 313/316 [01:50<00:00,  3.36it/s]
# Examining chardet:  99%|#########9| 313/316 [01:50<00:00,  3.36it/s]
# Examining mpmath:  99%|#########9| 314/316 [01:50<00:00,  3.36it/s]
# Examining python-dateutil: 100%|#########9| 315/316 [01:50<00:00,  3.36it/s]
#
#
# Determining conflicts:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining conflict for pytest anaconda geopandas astropy:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining conflict for spyder pytest attrs:   0%|          | 1/316 [00:04<23:05,  4.40s/it]
# Examining conflict for spyder pytest attrs:   1%|          | 2/316 [00:04<11:30,  2.20s/it]
# Examining conflict for pytest mock pytables numba astropy:   1%|          | 2/316 [00:04<11:30,  2.20s/it]
# Examining conflict for pytest anaconda python-language-server jupyterlab_server path.py nbformat spyder path pluggy importlib_metadata keyring astropy jsonschema:   1%|          | 3/316 [00:05<11:28,  2.20s/it]
# Examining conflict for pytest anaconda python-language-server jupyterlab_server path.py nbformat spyder path pluggy importlib_metadata keyring astropy jsonschema:   1%|1         | 4/316 [00:05<08:42,  1.68s/it]
# Examining conflict for pytest anaconda python-language-server spyder pluggy astropy:   1%|1         | 4/316 [00:10<08:42,  1.68s/it]
# Examining conflict for pytest anaconda python-language-server spyder pluggy astropy:   2%|1         | 5/316 [00:10<13:28,  2.60s/it]
# Examining conflict for pytest wcwidth console_shortcut jupyter_client argon2-cffi glob2 ipywidgets cloudpickle geopandas msgpack-python astropy libcurl jedi six qtawesome greenlet _ipyw_jlab_nb_ext_conf pathtools sphinxcontrib-websupport isort numba xlwt pygments webencodings sortedcollections sympy bitarray flake8 branca jinja2 conda-package-handling curl python_abi asn1crypto powershell_shortcut zope urllib3 patsy pywavelets python-jsonrpc-server importlib-metadata pyreadline idna toolz intervaltree nbclient qtpy beautifulsoup4 sphinxcontrib-serializinghtml nltk typing_extensions zict more-itertools mistune partd unicodecsv mock lxml bottleneck conda-build itsdangerous simplegeneric docutils fsspec zipp traitlets sphinxcontrib-htmlhelp wheel anaconda-project imageio scipy jupyterlab pycodestyle toml psutil libssh2 filelock widgetsnbextension brotlipy prometheus_client menuinst xlsxwriter sphinxcontrib-applehelp pyflakes decorator html5lib pyopenssl prompt-toolkit krb5 pyyaml jupyter_core nose navigator-updater spyder parso backports.shutil_get_terminal_size py-lief ipykernel backports.functools_lru_cache pycurl json5 xlrd ipython distributed statsmodels anaconda-client h5py heapdict yapf nest-asyncio imagesize pywin32 geographiclib future pywin32-ctypes sphinxcontrib-qthelp qt pillow pyrsistent spyder-kernels ruamel_yaml backports pytz olefile click path.py qtconsole sphinxcontrib-jsmath atomicwrites bcrypt importlib_metadata wrapt pathlib2 python lazy-object-proxy numpy terminado conda backports.weakref markupsafe win_unicode_console anaconda python-language-server tornado watchdog sphinxcontrib-devhelp pandocfilters testpath werkzeug colorama cython astroid jupyter_console comtypes bokeh paramiko send2trash networkx pip setuptools packaging multipledispatch pydocstyle regex pkginfo sortedcontainers notebook locket libarchive pluggy seaborn alabaster pickleshare requests jupyterlab_pygments iniconfig sip wincertstore diff-match-patch pyodbc jdcal scikit-image pep8 nbconvert flask llvmlite contextlib2 ply prompt_toolkit qdarkstyle soupsieve attrs path sqlalchemy snowballstemmer ipython_genutils tblib win_inet_pton pycparser babel zope.interface scikit-learn rope numpy-base pyparsing fastcache python-libarchive-c bkcharts xmltodict entrypoints anaconda-navigator numpydoc dask-core folium openpyxl et_xmlfile jupyterlab_server pyqt async_generator pysocks sphinx certifi boto tqdm clyent matplotlib singledispatch mkl-service mkl_random openssl ujson jsonschema threadpoolctl cytoolz tifffile rtree kiwisolver geopy keyring pyzmq backports.tempfile py pylint matplotlib-base cryptography backcall xlwings cffi numexpr pytables sphinxcontrib pywinpty argh zope.event dask mccabe pexpect cycler joblib jupyter mkl_fft gevent conda-verify nbformat chardet mpmath pandas python-dateutil bleach autopep8 pycosat pynacl defusedxml:   2%|1         | 5/316 [00:14<13:28,  2.60s/it]
# Examining conflict for pytest wcwidth console_shortcut jupyter_client argon2-cffi glob2 ipywidgets cloudpickle geopandas msgpack-python astropy libcurl jedi six qtawesome greenlet _ipyw_jlab_nb_ext_conf pathtools sphinxcontrib-websupport isort numba xlwt pygments webencodings sortedcollections sympy bitarray flake8 branca jinja2 conda-package-handling curl python_abi asn1crypto powershell_shortcut zope urllib3 patsy pywavelets python-jsonrpc-server importlib-metadata pyreadline idna toolz intervaltree nbclient qtpy beautifulsoup4 sphinxcontrib-serializinghtml nltk typing_extensions zict more-itertools mistune partd unicodecsv mock lxml bottleneck conda-build itsdangerous simplegeneric docutils fsspec zipp traitlets sphinxcontrib-htmlhelp wheel anaconda-project imageio scipy jupyterlab pycodestyle toml psutil libssh2 filelock widgetsnbextension brotlipy prometheus_client menuinst xlsxwriter sphinxcontrib-applehelp pyflakes decorator html5lib pyopenssl prompt-toolkit krb5 pyyaml jupyter_core nose navigator-updater spyder parso backports.shutil_get_terminal_size py-lief ipykernel backports.functools_lru_cache pycurl json5 xlrd ipython distributed statsmodels anaconda-client h5py heapdict yapf nest-asyncio imagesize pywin32 geographiclib future pywin32-ctypes sphinxcontrib-qthelp qt pillow pyrsistent spyder-kernels ruamel_yaml backports pytz olefile click path.py qtconsole sphinxcontrib-jsmath atomicwrites bcrypt importlib_metadata wrapt pathlib2 python lazy-object-proxy numpy terminado conda backports.weakref markupsafe win_unicode_console anaconda python-language-server tornado watchdog sphinxcontrib-devhelp pandocfilters testpath werkzeug colorama cython astroid jupyter_console comtypes bokeh paramiko send2trash networkx pip setuptools packaging multipledispatch pydocstyle regex pkginfo sortedcontainers notebook locket libarchive pluggy seaborn alabaster pickleshare requests jupyterlab_pygments iniconfig sip wincertstore diff-match-patch pyodbc jdcal scikit-image pep8 nbconvert flask llvmlite contextlib2 ply prompt_toolkit qdarkstyle soupsieve attrs path sqlalchemy snowballstemmer ipython_genutils tblib win_inet_pton pycparser babel zope.interface scikit-learn rope numpy-base pyparsing fastcache python-libarchive-c bkcharts xmltodict entrypoints anaconda-navigator numpydoc dask-core folium openpyxl et_xmlfile jupyterlab_server pyqt async_generator pysocks sphinx certifi boto tqdm clyent matplotlib singledispatch mkl-service mkl_random openssl ujson jsonschema threadpoolctl cytoolz tifffile rtree kiwisolver geopy keyring pyzmq backports.tempfile py pylint matplotlib-base cryptography backcall xlwings cffi numexpr pytables sphinxcontrib pywinpty argh zope.event dask mccabe pexpect cycler joblib jupyter mkl_fft gevent conda-verify nbformat chardet mpmath pandas python-dateutil bleach autopep8 pycosat pynacl defusedxml:   2%|1         | 6/316 [00:14<16:28,  3.19s/it]
# Examining conflict for pytest wcwidth console_shortcut jupyter_client argon2-cffi glob2 ipywidgets cloudpickle geopandas msgpack-python astropy jedi six qtawesome greenlet _ipyw_jlab_nb_ext_conf pathtools sphinxcontrib-websupport isort numba xlwt pygments webencodings sortedcollections sympy bitarray flake8 branca jinja2 python_abi conda-package-handling powershell_shortcut asn1crypto zope urllib3 patsy pywavelets python-jsonrpc-server importlib-metadata pyreadline idna toolz intervaltree nbclient qtpy beautifulsoup4 sphinxcontrib-serializinghtml nltk typing_extensions zict more-itertools mistune partd unicodecsv mock lxml bottleneck conda-build itsdangerous simplegeneric docutils fsspec zipp traitlets sphinxcontrib-htmlhelp wheel anaconda-project imageio scipy jupyterlab pycodestyle toml psutil filelock widgetsnbextension brotlipy prometheus_client menuinst xlsxwriter sphinxcontrib-applehelp pyflakes decorator html5lib pyopenssl prompt-toolkit pyyaml jupyter_core nose navigator-updater spyder parso backports.shutil_get_terminal_size py-lief ipykernel backports.functools_lru_cache pycurl json5 xlrd ipython distributed statsmodels get_terminal_size anaconda-client h5py heapdict yapf nest-asyncio imagesize pywin32 geographiclib future pywin32-ctypes sphinxcontrib-qthelp pillow pyrsistent spyder-kernels ruamel_yaml backports pytz olefile click path.py qtconsole sphinxcontrib-jsmath atomicwrites bcrypt importlib_metadata wrapt pathlib2 python lazy-object-proxy numpy terminado conda backports.weakref markupsafe win_unicode_console anaconda python-language-server tornado watchdog sphinxcontrib-devhelp pandocfilters testpath werkzeug colorama cython astroid jupyter_console comtypes bokeh paramiko send2trash networkx pip setuptools packaging multipledispatch pydocstyle regex pkginfo sortedcontainers notebook locket pluggy seaborn alabaster pickleshare requests jupyterlab_pygments iniconfig sip wincertstore diff-match-patch pyodbc jdcal scikit-image pep8 nbconvert flask llvmlite contextlib2 ply prompt_toolkit qdarkstyle soupsieve attrs path sqlalchemy snowballstemmer ipython_genutils tblib win_inet_pton pycparser babel zope.interface scikit-learn rope numpy-base pyparsing fastcache python-libarchive-c bkcharts xmltodict entrypoints anaconda-navigator numpydoc dask-core folium openpyxl et_xmlfile jupyterlab_server pyqt async_generator pysocks sphinx certifi boto tqdm clyent matplotlib singledispatch mkl-service mkl_random ujson jsonschema threadpoolctl cytoolz tifffile rtree kiwisolver geopy keyring pyzmq backports.tempfile py pylint matplotlib-base cryptography backcall xlwings cffi numexpr pytables sphinxcontrib pywinpty argh zope.event dask mccabe pexpect cycler joblib jupyter mkl_fft gevent conda-verify nbformat chardet mpmath pandas python-dateutil bleach autopep8 pycosat pynacl defusedxml:   2%|1         | 6/316 [00:32<16:28,  3.19s/it]
# Examining conflict for pytest wcwidth console_shortcut jupyter_client argon2-cffi glob2 ipywidgets cloudpickle geopandas msgpack-python astropy jedi six qtawesome greenlet _ipyw_jlab_nb_ext_conf pathtools sphinxcontrib-websupport isort numba xlwt pygments webencodings sortedcollections sympy bitarray flake8 branca jinja2 python_abi conda-package-handling powershell_shortcut asn1crypto zope urllib3 patsy pywavelets python-jsonrpc-server importlib-metadata pyreadline idna toolz intervaltree nbclient qtpy beautifulsoup4 sphinxcontrib-serializinghtml nltk typing_extensions zict more-itertools mistune partd unicodecsv mock lxml bottleneck conda-build itsdangerous simplegeneric docutils fsspec zipp traitlets sphinxcontrib-htmlhelp wheel anaconda-project imageio scipy jupyterlab pycodestyle toml psutil filelock widgetsnbextension brotlipy prometheus_client menuinst xlsxwriter sphinxcontrib-applehelp pyflakes decorator html5lib pyopenssl prompt-toolkit pyyaml jupyter_core nose navigator-updater spyder parso backports.shutil_get_terminal_size py-lief ipykernel backports.functools_lru_cache pycurl json5 xlrd ipython distributed statsmodels get_terminal_size anaconda-client h5py heapdict yapf nest-asyncio imagesize pywin32 geographiclib future pywin32-ctypes sphinxcontrib-qthelp pillow pyrsistent spyder-kernels ruamel_yaml backports pytz olefile click path.py qtconsole sphinxcontrib-jsmath atomicwrites bcrypt importlib_metadata wrapt pathlib2 python lazy-object-proxy numpy terminado conda backports.weakref markupsafe win_unicode_console anaconda python-language-server tornado watchdog sphinxcontrib-devhelp pandocfilters testpath werkzeug colorama cython astroid jupyter_console comtypes bokeh paramiko send2trash networkx pip setuptools packaging multipledispatch pydocstyle regex pkginfo sortedcontainers notebook locket pluggy seaborn alabaster pickleshare requests jupyterlab_pygments iniconfig sip wincertstore diff-match-patch pyodbc jdcal scikit-image pep8 nbconvert flask llvmlite contextlib2 ply prompt_toolkit qdarkstyle soupsieve attrs path sqlalchemy snowballstemmer ipython_genutils tblib win_inet_pton pycparser babel zope.interface scikit-learn rope numpy-base pyparsing fastcache python-libarchive-c bkcharts xmltodict entrypoints anaconda-navigator numpydoc dask-core folium openpyxl et_xmlfile jupyterlab_server pyqt async_generator pysocks sphinx certifi boto tqdm clyent matplotlib singledispatch mkl-service mkl_random ujson jsonschema threadpoolctl cytoolz tifffile rtree kiwisolver geopy keyring pyzmq backports.tempfile py pylint matplotlib-base cryptography backcall xlwings cffi numexpr pytables sphinxcontrib pywinpty argh zope.event dask mccabe pexpect cycler joblib jupyter mkl_fft gevent conda-verify nbformat chardet mpmath pandas python-dateutil bleach autopep8 pycosat pynacl defusedxml:   2%|2         | 7/316 [00:32<38:24,  7.46s/it]
# ...
#
# Package libllvm9 conflicts for:
# llvmlite -> libllvm9
# numba -> llvmlite[version='>=0.33.0'] -> libllvm9
#
# Package isort conflicts for:
# anaconda==2020.11 -> pylint==2.6.0=py37_0 -> isort[version='>=4.2.5,<6']
# pylint -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# anaconda==2020.11 -> isort==5.6.4=py_0
# python-language-server -> pylint[version='>=2.5.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
# spyder -> pylint[version='>=1.0'] -> isort[version='>=4.2.5|>=4.2.5,<5|>=4.2.5,<6']
#
# Package pyasn1 conflicts for:
# prometheus_client -> twisted -> pyasn1
# paramiko -> pyasn1[version='>=0.1.7']
# spyder -> paramiko[version='>=2.4.0'] -> pyasn1[version='>=0.1.7']
#
# Package pylint conflicts for:
# python-language-server -> pylint[version='>=2.5.0']
# spyder -> python-language-server[version='>=0.36.1,<1.0.0'] -> pylint[version='>=2.5.0']
# spyder -> pylint[version='>=0.25|>=1.0']
# anaconda==2020.11 -> pylint==2.6.0[build='py37_0|py38_0']
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> pylint[version='>=1.0']
#
# Package pywin32-ctypes conflicts for:
# anaconda==2020.11 -> pywin32-ctypes==0.2.0[build='py37_1001|py38_1000']
# keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# anaconda==2020.11 -> keyring==21.4.0=py37_1 -> pywin32-ctypes
# spyder -> keyring[version='>=17.0.0'] -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
#
# Package m2w64-gmp conflicts for:
# anaconda==2020.11 -> m2w64-gcc-libs==5.3.0=7 -> m2w64-gmp
# m2w64-gcc-libs -> m2w64-gmp
# pywinpty -> m2w64-gcc-libs -> m2w64-gmp
# m2w64-gcc-libs-core -> m2w64-gmp
# anaconda==2020.11 -> m2w64-gmp==6.1.0=2
# m2w64-gcc-libgfortran -> m2w64-gcc-libs-core -> m2w64-gmp
#
# Package sphinxcontrib-htmlhelp conflicts for:
# anaconda==2020.11 -> sphinxcontrib-htmlhelp==1.0.3=py_0
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-htmlhelp
# sphinx -> sphinxcontrib-htmlhelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-htmlhelp
# numpydoc -> sphinx -> sphinxcontrib-htmlhelp
#
# Package sortedcontainers conflicts for:
# distributed -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# attrs -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# sortedcollections -> sortedcontainers[version='>=2.0']
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> sortedcontainers[version='!=2.0.0,!=2.0.1|>=2.0']
# dask -> distributed[version='>=2020.12.0'] -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# intervaltree -> sortedcontainers
# spyder -> intervaltree[version='>=3.0.2'] -> sortedcontainers
# anaconda==2020.11 -> sortedcontainers==2.2.2=py_0
#
# Package pickleshare conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> pickleshare
# anaconda==2020.11 -> ipython==7.19.0=py37hd4e2768_0 -> pickleshare[version='>=0.4']
# spyder -> pickleshare[version='>=0.4']
# spyder-kernels -> ipython[version='>=7.6.0'] -> pickleshare
# ipywidgets -> ipython[version='>=4.0.0'] -> pickleshare
# ipython -> pickleshare
# jupyter_console -> ipython -> pickleshare
# anaconda==2020.11 -> pickleshare==0.7.5[build='py37_1001|py38_1000']
#
# Package locket conflicts for:
# dask -> partd[version='>=0.3.10'] -> locket
# anaconda==2020.11 -> locket==0.2.0[build='py37_1|py38_1']
# partd -> locket
# anaconda==2020.11 -> partd==1.1.0=py_0 -> locket
#
# Package pynacl conflicts for:
# spyder -> paramiko[version='>=2.4.0'] -> pynacl[version='>=1.0.1']
# anaconda==2020.11 -> pynacl==1.4.0[build='py37h62dcd97_1|py38h62dcd97_1']
# paramiko -> pynacl[version='>=1.0.1']
# anaconda==2020.11 -> paramiko==2.7.2=py_0 -> pynacl[version='>=1.0.1']
#
# Package mistune conflicts for:
# spyder -> nbconvert[version='>=4.0'] -> mistune[version='>0.6|>=0.8.1']
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> mistune[version='>=0.8.1']
# jupyter -> nbconvert -> mistune[version='>0.6|>=0.8.1']
# anaconda==2020.11 -> mistune==0.8.4[build='py38he774522_1000|py37hfa6e2cd_1001']
# notebook -> nbconvert -> mistune[version='>0.6|>=0.8.1']
# nbconvert -> mistune[version='>0.6|>=0.8.1']
#
# Package jdcal conflicts for:
# anaconda==2020.11 -> jdcal==1.4.1=py_0
# openpyxl -> jdcal
# anaconda==2020.11 -> openpyxl==3.0.5=py_0 -> jdcal
#
# Package libxslt conflicts for:
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# anaconda==2020.11 -> lxml==4.6.1=py37h1350720_0 -> libxslt[version='>=1.1.34,<2.0a0']
# anaconda==2020.11 -> libxslt==1.1.34=he774522_0
#
# Package hypothesis conflicts for:
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
# attrs -> hypothesis
# astropy -> pytest-astropy -> hypothesis
#
# Package contextvars conflicts for:
# dask -> distributed[version='>=2020.12.0'] -> contextvars
# distributed -> contextvars
#
# Package pexpect conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> pexpect[version='>=4.4.0']
# anaconda==2020.11 -> pexpect==4.8.0[build='py37_1|py38_0']
# spyder -> pexpect[version='>=4.4.0']
#
# Package zope.interface conflicts for:
# anaconda==2020.11 -> gevent==20.9.0=py37he774522_0 -> zope.interface
# prometheus_client -> twisted -> zope.interface[version='>=4.0.2|>=4.4.2']
# attrs -> zope.interface
# gevent -> zope.interface
# anaconda==2020.11 -> zope.interface==5.1.2[build='py38he774522_0|py37he774522_0']
#
# Package sphinx conflicts for:
# spyder -> sphinx[version='>=0.6.6']
# numpydoc -> sphinx
# anaconda==2020.11 -> sphinx==3.2.1=py_0
# jedi -> numpydoc -> sphinx
# anaconda==2020.11 -> numpydoc==1.1.0=pyhd3eb1b0_1 -> sphinx[version='>=0.6.6']
#
# Package rope conflicts for:
# spyder -> rope[version='>=0.10.5|>=0.9.4']
# anaconda==2020.11 -> rope==0.18.0=py_0
# python-language-server -> rope[version='>=0.10.5']
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> rope[version='>=0.10.5']
#
# Package _low_priority conflicts for:
# python-libarchive-c -> libarchive -> _low_priority
# libarchive -> _low_priority
# conda-build -> libarchive -> _low_priority
#
# Package libcurl conflicts for:
# curl -> libcurl[version='7.57.0|7.58.0|7.58.0|7.59.0|7.59.0|7.60.0|7.60.0|7.61.0|7.61.0|7.61.1|7.61.1|7.61.1|7.62.0|7.62.0|7.63.0|7.63.0|7.63.0|7.63.0|7.64.0|7.64.0|7.64.1|7.64.1|7.65.2|7.65.2|7.65.3|7.65.3|7.67.0|7.68.0|7.69.1|7.71.0|7.71.1',build='h2a8f88b_0|h2a8f88b_0|h7a46e7a_1000|h7a46e7a_2|h2a8f88b_2|h2a8f88b_0|h2a8f88b_1|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_1000|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h7a46e7a_0|h7602738_0|h7602738_0|h7a46e7a_0|h0990ea7_0|hc4dcbb0_0|hc4dcbb0_0|h0990ea7_0|h7602738_0|h7a46e7a_0|h7a46e7a_0']
# anaconda==2020.11 -> libcurl==7.71.1=h2a8f88b_1
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl[version='7.57.0|7.58.0|7.58.0|7.59.0|7.59.0|7.60.0|7.60.0|7.61.0|7.61.0|7.61.1|7.61.1|7.61.1|7.62.0|7.62.0|7.63.0|7.63.0|7.63.0|7.63.0|7.64.0|7.64.0|7.64.1|7.64.1|7.65.2|7.65.2|7.65.3|7.65.3|7.67.0|7.68.0|7.69.1|7.71.0|7.71.1',build='h2a8f88b_0|h2a8f88b_0|h7a46e7a_1000|h7a46e7a_2|h2a8f88b_2|h2a8f88b_0|h2a8f88b_1|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h2a8f88b_1000|h7a46e7a_0|h2a8f88b_0|h7a46e7a_0|h7a46e7a_0|h7602738_0|h7602738_0|h7a46e7a_0|h0990ea7_0|hc4dcbb0_0|hc4dcbb0_0|h0990ea7_0|h7602738_0|h7a46e7a_0|h7a46e7a_0']
# anaconda==2020.11 -> pycurl==7.43.0.6=py37h7a1dbc1_0 -> libcurl[version='>=7.71.1,<8.0a0']
# pycurl -> libcurl[version='>=7.60.0,<8.0a0|>=7.61.0,<8.0a0|>=7.63.0,<8.0a0|>=7.64.1,<8.0a0|>=7.65.3,<8.0a0|>=7.67.0,<8.0a0|>=7.71.1,<8.0a0']
#
# Package pkginfo conflicts for:
# anaconda==2020.11 -> pkginfo==1.6.1[build='py38haa95532_0|py37haa95532_0']
# conda-build -> pkginfo
#
# Package werkzeug conflicts for:
# anaconda==2020.11 -> werkzeug==1.0.1=py_0
# anaconda==2020.11 -> flask==1.1.2=py_0 -> werkzeug[version='>=0.15']
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.7,<1.0.0']
#
# Package qtconsole conflicts for:
# jupyter -> qtconsole
# anaconda==2020.11 -> qtconsole==4.7.7=py_0
# spyder -> qtconsole[version='>=4.2|>=4.6.0|>=4.7.7']
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> qtconsole[version='>=4.6.0']
#
# Package libiconv conflicts for:
# conda-package-handling -> libarchive[version='>=3.3.3'] -> libiconv[version='>=1.15,<2.0a0']
# libxml2 -> libiconv[version='>=1.15,<2.0a0']
# libxslt -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# libarchive -> libxml2[version='>=2.9.4,<2.10.0a0'] -> libiconv
# conda-build -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# python-libarchive-c -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# libarchive -> libiconv[version='>=1.15,<2.0a0']
# anaconda==2020.11 -> libiconv==1.15=h1df5818_7
# lxml -> libxml2[version='>=2.9.10,<2.10.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# anaconda==2020.11 -> libarchive==3.4.2=h5e25573_0 -> libiconv[version='>=1.15,<2.0a0']
#
# Package typing_extensions conflicts for:
# anaconda==2020.11 -> typing_extensions==3.7.4.3=py_0
# anaconda==2020.11 -> bokeh==2.2.3=py37_0 -> typing_extensions[version='>=3.7.4']
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> typing_extensions[version='>=3.7.4']
# bokeh -> typing_extensions[version='>=3.7.4']
#
# Package intervaltree conflicts for:
# spyder -> intervaltree[version='>=3.0.2']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> intervaltree
# anaconda==2020.11 -> intervaltree==3.1.0=py_0
#
# Package regex conflicts for:
# anaconda==2020.11 -> nltk==3.5=py_0 -> regex
# anaconda==2020.11 -> regex==2020.10.15[build='py38he774522_0|py37he774522_0']
# nltk -> regex
#
# Package rtree conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> rtree[version='>=0.8.3']
# geopandas -> rtree
# anaconda==2020.11 -> rtree==0.9.4[build='py38h21ff451_1|py37h21ff451_1']
# spyder -> rtree[version='>=0.8.3']
#
# Package pandas conflicts for:
# dask -> pandas[version='>=0.19.0|>=0.21.0|>=0.23.0|>=0.25.0']
# anaconda==2020.11 -> bkcharts==0.2=py37_0 -> pandas[version='>=0.21|>=0.22.0|>=0.23.0']
# bkcharts -> pandas
# anaconda==2020.11 -> pandas==1.1.3[build='py37ha925a31_0|py38ha925a31_0']
# seaborn -> statsmodels[version='>=0.5.0'] -> pandas[version='>=0.14|>=0.21']
# statsmodels -> pandas[version='>=0.14|>=0.21']
# geopandas -> pandas[version='>=0.23']
# dask -> bokeh -> pandas
# geopandas -> mapclassify -> pandas[version='>=1.0']
# bokeh -> pandas
# scikit-image -> dask[version='>=0.5'] -> pandas[version='>=0.19.0|>=0.21.0|>=0.23.0|>=0.25.0']
# seaborn -> pandas[version='>=0.14.0|>=0.22.0']
#
# Package winpty conflicts for:
# pywinpty -> winpty[version='>=0.4.3,<1.0a0']
# terminado -> pywinpty -> winpty[version='>=0.4.3,<1.0a0']
# anaconda==2020.11 -> winpty==0.4.3=4
# anaconda==2020.11 -> pywinpty==0.5.7=py37_0 -> winpty
#
# Package async_generator conflicts for:
# anaconda==2020.11 -> nbclient==0.5.1=py_0 -> async_generator
# anaconda==2020.11 -> async_generator==1.10[build='py37h28b3542_0|py_0']
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0'] -> async_generator
# nbclient -> async_generator
#
# Package pympler conflicts for:
# attrs -> pympler
# spyder -> pympler
# pytest -> attrs[version='>=17.2.0'] -> pympler
#
# Package comtypes conflicts for:
# xlwings -> comtypes
# anaconda==2020.11 -> comtypes==1.1.7[build='py37_1001|py38_1001']
# anaconda==2020.11 -> xlwings==0.20.8=py37_0 -> comtypes
#
# Package sqlalchemy conflicts for:
# anaconda==2020.11 -> sqlalchemy==1.3.20[build='py37h2bbff1b_0|py38h2bbff1b_0']
# geopandas -> sqlalchemy
#
# Package beautifulsoup4 conflicts for:
# conda-build -> beautifulsoup4
# anaconda==2020.11 -> beautifulsoup4==4.9.3=pyhb0f4dca_0
# soupsieve -> beautifulsoup4
#
# Package imageio conflicts for:
# anaconda==2020.11 -> imageio==2.9.0=py_0
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
# anaconda==2020.11 -> scikit-image==0.17.2=py37h1e1f486_0 -> imageio[version='>=2.3.0']
#
# Package sphinxcontrib-jsmath conflicts for:
# anaconda==2020.11 -> sphinxcontrib-jsmath==1.0.1=py_0
# sphinx -> sphinxcontrib-jsmath
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-jsmath
# numpydoc -> sphinx -> sphinxcontrib-jsmath
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-jsmath
#
# Package mpmath conflicts for:
# sympy -> mpmath[version='>=0.19']
# anaconda==2020.11 -> mpmath==1.1.0[build='py37_0|py38_0']
# anaconda==2020.11 -> sympy==1.6.2=py37haa95532_1 -> mpmath[version='>=0.19']
#
# Package m2w64-gcc-libs-core conflicts for:
# anaconda==2020.11 -> m2w64-gcc-libgfortran==5.3.0=6 -> m2w64-gcc-libs-core
# anaconda==2020.11 -> m2w64-gcc-libs-core==5.3.0=7
# terminado -> pywinpty -> m2w64-gcc-libs-core
# m2w64-gcc-libs -> m2w64-gcc-libs-core
# m2w64-gcc-libgfortran -> m2w64-gcc-libs-core
# pywinpty -> m2w64-gcc-libs-core
#
# Package pluggy conflicts for:
# python-language-server -> pluggy
# astropy -> pytest[version='<4'] -> pluggy[version='>=0.12,<1.0|>=0.12,<1.0.0a1|>=0.5,<0.7|>=0.7|>=0.9,!=0.10,<1.0|>=0.9']
# anaconda==2020.11 -> pluggy==0.13.1[build='py37_0|py38_0']
# spyder -> python-language-server[version='>=0.36.1,<1.0.0'] -> pluggy
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> pluggy[version='>=0.12,<1.0']
#
# Package python_abi conflicts for:
# conda[version='>=4.9.2'] -> python_abi=3.8[build=*_cp38]
# conda-build -> conda[version='>=4.5'] -> python_abi=3.8[build=*_cp38]
#
# Package fsspec conflicts for:
# anaconda==2020.11 -> fsspec==0.8.3=py_0
# dask -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# scikit-image -> dask[version='>=0.5'] -> fsspec[version='>=0.4.0|>=0.5.1|>=0.6.0']
# anaconda==2020.11 -> dask==2.30.0=py_0 -> fsspec[version='>=0.6.0']
#
# Package backports.tempfile conflicts for:
# conda-verify -> backports.tempfile
# conda-build -> conda-verify -> backports.tempfile
#
# Package iniconfig conflicts for:
# astropy -> pytest -> iniconfig
# anaconda==2020.11 -> iniconfig==1.1.1=py_0
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> iniconfig
#
# Package pycosat conflicts for:
# conda-build -> conda[version='>=4.5'] -> pycosat[version='>=0.6.1|>=0.6.3']
# conda[version='>=4.9.2'] -> pycosat[version='>=0.6.3']
# anaconda==2020.11 -> pycosat==0.6.3[build='py38he774522_0|py37he774522_0']
#
# Package blosc conflicts for:
# pytables -> blosc[version='>=1.14.3,<2.0a0|>=1.14.4,<2.0a0|>=1.15.0,<2.0a0|>=1.16.3,<2.0a0|>=1.20.1,<2.0a0']
# tifffile -> imagecodecs -> blosc[version='>=1.20.1,<2.0a0']
# anaconda==2020.11 -> blosc==1.20.1=h7bd577a_0
# anaconda==2020.11 -> pytables==3.6.1=py37h1da0976_0 -> blosc[version='>=1.16.3,<2.0a0']
#
# Package win_unicode_console conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> win_unicode_console[version='>=0.5']
# ipython -> win_unicode_console[version='>=0.5']
# anaconda==2020.11 -> win_unicode_console==0.5[build='py37_0|py38_0']
# ipywidgets -> ipython[version='>=4.0.0'] -> win_unicode_console[version='>=0.5']
# jupyter_console -> ipython -> win_unicode_console[version='>=0.5']
#
# Package dask conflicts for:
# anaconda==2020.11 -> dask==2.30.0=py_0
# scikit-image -> dask[version='>=0.5']
#
# Package spyder-kernels conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> spyder-kernels[version='>=1.9.4,<1.10.0']
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2020.11 -> spyder-kernels==1.9.4[build='py37_0|py38_0']
#
# Package scikit-learn conflicts for:
# geopandas -> mapclassify -> scikit-learn
# anaconda==2020.11 -> scikit-learn==0.23.2[build='py38h47e9c7a_0|py37h47e9c7a_0']
# nltk -> scikit-learn
#
# Package llvmlite conflicts for:
# anaconda==2020.11 -> llvmlite==0.34.0[build='py38h1a82afc_4|py37h1a82afc_4']
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35']
# anaconda==2020.11 -> numba==0.51.2=py37hf9181ef_1 -> llvmlite[version='>=0.34.0,<0.35']
#
# Package mock conflicts for:
# anaconda==2020.11 -> pytables==3.6.1=py37h1da0976_0 -> mock
# anaconda==2020.11 -> mock==4.0.2=py_0
# pytables -> mock
#
# Package pbr conflicts for:
# pytables -> mock -> pbr
# mock -> pbr
#
# Package jupyterlab conflicts for:
# anaconda==2020.11 -> jupyterlab==2.2.6=py_0
# _ipyw_jlab_nb_ext_conf -> jupyterlab
#
# Package snappy conflicts for:
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# pytables -> blosc[version='>=1.16.3,<2.0a0'] -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# tifffile -> imagecodecs -> snappy[version='>=1.1.8,<2.0a0']

# %%
import folium # map rendering library
import requests
import numpy as np
import random
import json
import pandas as pd
from pandas import json_normalize

# %%
from geopy.geocoders import Nominatim

# %%
address = 'New York,NY'
geolocator = Nominatim(user_agent="newyork_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of New York re {},{}.'.format(latitude,longitude));
# Out:
# The geographical coordinate of New York re 40.7127281,-74.0060152.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nyc_geo = r'nyc-neighborhoods.geo.json' # geojson file
with open('.\\data\\nyc-neighborhoods.geo.json') as json_nyc_data:
    nyc_as_json = json.load(json_nyc_data)
nyc_as_json
df_nyc = pd.DataFrame(columns=["Name","Total"])
df_nyc = df_nyc.append({"Name":"Todt Hill-Emerson Hill-Heartland Village-Lighthouse Hill", "Total":100},ignore_index=True)
df_nyc.head()
# Out:
#                                                 Name Total
# 0  Todt Hill-Emerson Hill-Heartland Village-Light...   100

# %%
map_newyork.choropleth(
    geo_data=".\\data\\"+nyc_geo,
    data=df_nyc,
    columns=['Name', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='New York'
)

# display map
map_newyork
# Out:
# C:\Users\psharer\anaconda3\lib\site-packages\folium\folium.py:411: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json

# %%
with open('.\\data\\newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data["features"]

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
CLIENT_ID = 'ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420' # your Foursquare ID
CLIENT_SECRET = 'IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420
# CLIENT_SECRET:IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def get_venues_dataframe(lat,lon,radius,search_query,neighborhood):
    CLIENT_ID = 'ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420' # your Foursquare ID
    CLIENT_SECRET = 'IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA' # your Foursquare Secret
    VERSION = '20180604'
    LIMIT = 30
    print('Your credentails:')
    print('CLIENT_ID: ' + CLIENT_ID)
    print('CLIENT_SECRET:' + CLIENT_SECRET)
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]
    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
    # clean column names by keeping only last term
    dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
    dataframe_filtered['neighborhood'] = neighborhood;
    cols = dataframe_filtered.columns.tolist()
    cols = [cols[0],cols[len(cols)-1]]+cols[1:len(cols)-2]
    print(cols)
    dataframe_filtered = dataframe_filtered[cols];
    return dataframe_filtered

# %%
radius = 1500
get_venues_dataframe(latitude,longitude,radius,'Nightclub','Wakefield')
# Out:
# Your credentails:
# CLIENT_ID: ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420
# CLIENT_SECRET:IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA
# ['name', 'neighborhood', 'categories', 'address', 'lat', 'lng', 'labeledLatLngs', 'distance', 'postalCode', 'cc', 'city', 'state', 'country', 'formattedAddress', 'crossStreet']
#                                               name neighborhood  \
# 0                                 VANDAL Nightclub    Wakefield
# 1                   Golden Unicorn Restaurant 麒麟金閣    Wakefield
# 2  KTU Professional Radio DJ Night Club and Lounge    Wakefield
# 3                                   Ave night club    Wakefield
#
#            categories                    address        lat        lng  \
# 0           Nightclub      199 Bowery Lowr Level  40.721201 -73.993455
# 1  Dim Sum Restaurant              18 E Broadway  40.713629 -73.997230
# 2           Nightclub  32 Avenue of the Americas  40.720443 -74.005319
# 3                 Pub                        NaN  40.723527 -73.997321
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.72120070108200...      1418      10002  US
# 1  [{'label': 'display', 'lat': 40.71362850464683...       748      10002  US
# 2  [{'label': 'display', 'lat': 40.720443, 'lng':...       860      10013  US
# 3  [{'label': 'display', 'lat': 40.7235273, 'lng'...      1408      10012  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
#
#                                     formattedAddress      crossStreet
# 0  [199 Bowery Lowr Level, New York, NY 10002, Un...              NaN
# 1  [18 E Broadway (at Catherine St), New York, NY...  at Catherine St
# 2  [32 Avenue of the Americas, New York, NY 10013...              NaN
# 3  [116 10th Ave, New York, NY 10012, United States]     116 10th Ave

# %%
search_query = 'Nightclub'
radius = 1500
print(search_query + ' .... OK!')
# Out:
# Nightclub .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ff3e930f6bc1c09d3cb9e51'},
#  'response': {'venues': [{'id': '5caf985d666116002ca0eab5',
#     'name': 'VANDAL Nightclub',
#     'location': {'address': '199 Bowery Lowr Level',
#      'lat': 40.721200701082005,
#      'lng': -73.99345526074791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.721200701082005,
#        'lng': -73.99345526074791}],
#      'distance': 1418,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['199 Bowery Lowr Level',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609820464',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ece31ee3',
#     'name': 'Golden Unicorn Restaurant 麒麟金閣',
#     'location': {'address': '18 E Broadway',
#      'crossStreet': 'at Catherine St',
#      'lat': 40.713628504646834,
#      'lng': -73.99723023176193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713628504646834,
#        'lng': -73.99723023176193}],
#      'distance': 748,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E Broadway (at Catherine St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2197825',
#      'url': 'https://www.seamless.com/menu/golden-unicorn-broadway-18-e-broadway-new-york/2197825?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2197825',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '72966848'},
#     'referralId': 'v-1609820464',
#     'hasPerk': False},
#    {'id': '4c177cb57bf1d13a4235e881',
#     'name': 'KTU Professional Radio DJ Night Club and Lounge',
#     'location': {'address': '32 Avenue of the Americas',
#      'lat': 40.720443,
#      'lng': -74.005319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.720443,
#        'lng': -74.005319}],
#      'distance': 860,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32 Avenue of the Americas',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609820464',
#     'hasPerk': False},
#    {'id': '4e3e3828aeb73139a1846b2e',
#     'name': 'Ave night club',
#     'location': {'crossStreet': '116 10th Ave',
#      'lat': 40.7235273,
#      'lng': -73.997321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7235273,
#        'lng': -73.997321}],
#      'distance': 1408,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['116 10th Ave',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609820464',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                             name  \
# 0  5caf985d666116002ca0eab5                                 VANDAL Nightclub
# 1  3fd66200f964a520ece31ee3                   Golden Unicorn Restaurant 麒麟金閣
# 2  4c177cb57bf1d13a4235e881  KTU Professional Radio DJ Night Club and Lounge
# 3  4e3e3828aeb73139a1846b2e                                   Ave night club
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609820464    False
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1609820464    False
# 2  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609820464    False
# 3  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1609820464    False
#
#             location.address  location.lat  location.lng  \
# 0      199 Bowery Lowr Level     40.721201    -73.993455
# 1              18 E Broadway     40.713629    -73.997230
# 2  32 Avenue of the Americas     40.720443    -74.005319
# 3                        NaN     40.723527    -73.997321
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 40.72120070108200...               1418  ...
# 1  [{'label': 'display', 'lat': 40.71362850464683...                748  ...
# 2  [{'label': 'display', 'lat': 40.720443, 'lng':...                860  ...
# 3  [{'label': 'display', 'lat': 40.7235273, 'lng'...               1408  ...
#
#   location.country                          location.formattedAddress  \
# 0    United States  [199 Bowery Lowr Level, New York, NY 10002, Un...
# 1    United States  [18 E Broadway (at Catherine St), New York, NY...
# 2    United States  [32 Avenue of the Americas, New York, NY 10013...
# 3    United States  [116 10th Ave, New York, NY 10012, United States]
#
#   location.crossStreet delivery.id  \
# 0                  NaN         NaN
# 1      at Catherine St     2197825
# 2                  NaN         NaN
# 3         116 10th Ave         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1  https://www.seamless.com/menu/golden-unicorn-b...               seamless
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
#
#                 delivery.provider.icon.name venuePage.id
# 0                                       NaN          NaN
# 1  /delivery_provider_seamless_20180129.png     72966848
# 2                                       NaN          NaN
# 3                                       NaN          NaN
#
# [4 rows x 24 columns]

# %%
dataframe.head(10)
# Out:
#                          id                                             name  \
# 0  5caf985d666116002ca0eab5                                 VANDAL Nightclub
# 1  3fd66200f964a520ece31ee3                   Golden Unicorn Restaurant 麒麟金閣
# 2  4c177cb57bf1d13a4235e881  KTU Professional Radio DJ Night Club and Lounge
# 3  4e3e3828aeb73139a1846b2e                                   Ave night club
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609820464    False
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1609820464    False
# 2  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609820464    False
# 3  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1609820464    False
#
#             location.address  location.lat  location.lng  \
# 0      199 Bowery Lowr Level     40.721201    -73.993455
# 1              18 E Broadway     40.713629    -73.997230
# 2  32 Avenue of the Americas     40.720443    -74.005319
# 3                        NaN     40.723527    -73.997321
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 40.72120070108200...               1418  ...
# 1  [{'label': 'display', 'lat': 40.71362850464683...                748  ...
# 2  [{'label': 'display', 'lat': 40.720443, 'lng':...                860  ...
# 3  [{'label': 'display', 'lat': 40.7235273, 'lng'...               1408  ...
#
#   location.country                          location.formattedAddress  \
# 0    United States  [199 Bowery Lowr Level, New York, NY 10002, Un...
# 1    United States  [18 E Broadway (at Catherine St), New York, NY...
# 2    United States  [32 Avenue of the Americas, New York, NY 10013...
# 3    United States  [116 10th Ave, New York, NY 10012, United States]
#
#   location.crossStreet delivery.id  \
# 0                  NaN         NaN
# 1      at Catherine St     2197825
# 2                  NaN         NaN
# 3         116 10th Ave         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1  https://www.seamless.com/menu/golden-unicorn-b...               seamless
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
#
#                 delivery.provider.icon.name venuePage.id
# 0                                       NaN          NaN
# 1  /delivery_provider_seamless_20180129.png     72966848
# 2                                       NaN          NaN
# 3                                       NaN          NaN
#
# [4 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                               name          categories  \
# 0                                 VANDAL Nightclub           Nightclub
# 1                   Golden Unicorn Restaurant 麒麟金閣  Dim Sum Restaurant
# 2  KTU Professional Radio DJ Night Club and Lounge           Nightclub
# 3                                   Ave night club                 Pub
#
#                      address        lat        lng  \
# 0      199 Bowery Lowr Level  40.721201 -73.993455
# 1              18 E Broadway  40.713629 -73.997230
# 2  32 Avenue of the Americas  40.720443 -74.005319
# 3                        NaN  40.723527 -73.997321
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 40.72120070108200...      1418      10002  US
# 1  [{'label': 'display', 'lat': 40.71362850464683...       748      10002  US
# 2  [{'label': 'display', 'lat': 40.720443, 'lng':...       860      10013  US
# 3  [{'label': 'display', 'lat': 40.7235273, 'lng'...      1408      10012  US
#
#        city state        country  \
# 0  New York    NY  United States
# 1  New York    NY  United States
# 2  New York    NY  United States
# 3  New York    NY  United States
#
#                                     formattedAddress      crossStreet  \
# 0  [199 Bowery Lowr Level, New York, NY 10002, Un...              NaN
# 1  [18 E Broadway (at Catherine St), New York, NY...  at Catherine St
# 2  [32 Avenue of the Americas, New York, NY 10013...              NaN
# 3  [116 10th Ave, New York, NY 10012, United States]     116 10th Ave
#
#                          id
# 0  5caf985d666116002ca0eab5
# 1  3fd66200f964a520ece31ee3
# 2  4c177cb57bf1d13a4235e881
# 3  4e3e3828aeb73139a1846b2e

# %%
dataframe_filtered["lat"]
# Out:
# 0    40.721201
# 1    40.713629
# 2    40.720443
# 3    40.723527
# Name: lat, dtype: float64

# %%
for lat, lon, name in zip(dataframe_filtered["lat"],dataframe_filtered["lng"],dataframe_filtered["name"]):
    folium.CircleMarker(
    [lat,lon],
    radius=5,
    color='blue',
    popup=name,
    fill = True,
    fill_color='blue',
    fill_opacity=0.6,
    ).add_to(map_newyork)

# %%
for lat, lon, name in zip(neighborhoods["Latitude"],neighborhoods["Longitude"],neighborhoods["Neighborhood"]):
    folium.CircleMarker(
    [lat,lon],
    radius=5,
    color='red',
    popup=name,
    fill = True,
    fill_color='red',
    fill_opacity=0.6,
    ).add_to(map_newyork)

# %%
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !conda install -c conda-forge geopandas
# Out:
# ^C

# %%
import geopandas as gpd
from shapely.geometry import Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-19515517d005> in <module>
# ----> 1 import geopandas as gpd
#       2 from shapely.geometry import Polygon
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
points  = [-87.606708,41.816814 -87.606712,41.817080 -87.606717,41.817291 -87.606721,41.817507 -87.606727,41.817688 -87.606728,41.817733 -87.606730,41.817801 -87.606735,41.817944 -87.606743,41.818152 -87.606745,41.818310 -87.606747,41.818439 -87.606750,41.818618 -87.606753,41.818825 -87.606753,41.819040 -87.606753,41.819079 -87.606760,41.819345 -87.606767,41.819477 -87.606772,41.819572 -87.606772,41.819572 -87.606799,41.820071 -87.606804,41.820269 -87.606806,41.820382 -87.606809,41.820487 -87.606820,41.820956 -87.606823,41.821087 -87.606833,41.821503 -87.606845,41.822012 -87.606847,41.822127 -87.606853,41.822425 -87.606855,41.822729 -87.606859,41.823166 -87.606437,41.823306 -87.606873,41.823965 -87.606880,41.823963 -87.606916,41.823960 -87.607029,41.823958 -87.607327,41.823949 -87.608338,41.823937 -87.609587,41.823923 -87.609841,41.823921 -87.612136,41.823897 -87.612624,41.823891 -87.613076,41.823885 -87.614364,41.823869 -87.615148,41.823859 -87.615475,41.823855 -87.616109,41.823848 -87.616732,41.823838 -87.616997,41.823834 -87.617259,41.823830 -87.617710,41.823823 -87.617950,41.823820 -87.618214,41.823817 -87.618551,41.823813 -87.618862,41.823809 -87.619178,41.823805 -87.619988,41.823795 -87.620395,41.823790 -87.620953,41.823783 -87.621602,41.823775 -87.622230,41.823767 -87.622346,41.823766 -87.622408,41.823765 -87.623147,41.823756 -87.624268,41.823742 -87.624321,41.823741 -87