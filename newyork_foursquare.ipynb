# %%
# !conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\psharer\anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-2.1.0                |     pyhd3deb0d_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          64 KB
#
# The following packages will be UPDATED:
#
#   geopy                                  2.0.0-pyh9f0ad1d_0 --> 2.1.0-pyhd3deb0d_0
#
#
#
# Downloading and Extracting Packages
#
# geopy-2.1.0          | 64 KB     |            |   0%
# geopy-2.1.0          | 64 KB     | ##5        |  25%
# geopy-2.1.0          | 64 KB     | ########## | 100%
# geopy-2.1.0          | 64 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium # map rendering library
import requests
import numpy as np
import random
from pandas.io.json import json_normalize

# %%
from geopy.geocoders import Nominatim

# %%
address = 'New York,IL'
geolocator = Nominatim(user_agent="newyork_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of New York re {},{}.'.format(latitude,longitude));
# Out:
# The geographical coordinate of New York re 40.7127281,-74.0060152.

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420' # your Foursquare ID
CLIENT_SECRET = 'IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ARMIVQSQH4QPDIFSSJ25ZKW3D13AVXOKPM43G12HB2B1V420
# CLIENT_SECRET:IC3CBJ51FC2XYAGIZRVHUS3RHQ4IFIAPRV5GDGBFSEWI3ZNA

# %%
search_query = 'Nightclub'
radius = 1500
print(search_query + ' .... OK!')
# Out:
# Nightclub .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5febbfa4fb7e627cbeead158'},
#  'response': {'venues': [{'id': '5caf985d666116002ca0eab5',
#     'name': 'VANDAL Nightclub',
#     'location': {'address': '199 Bowery Lowr Level',
#      'lat': 40.721200701082005,
#      'lng': -73.99345526074791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.721200701082005,
#        'lng': -73.99345526074791}],
#      'distance': 1418,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['199 Bowery Lowr Level',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609285540',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520ece31ee3',
#     'name': 'Golden Unicorn Restaurant 麒麟金閣',
#     'location': {'address': '18 E Broadway',
#      'crossStreet': 'at Catherine St',
#      'lat': 40.713628504646834,
#      'lng': -73.99723023176193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713628504646834,
#        'lng': -73.99723023176193}],
#      'distance': 748,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E Broadway (at Catherine St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2197825',
#      'url': 'https://www.seamless.com/menu/golden-unicorn-broadway-18-e-broadway-new-york/2197825?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2197825',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '72966848'},
#     'referralId': 'v-1609285540',
#     'hasPerk': False},
#    {'id': '4c177cb57bf1d13a4235e881',
#     'name': 'KTU Professional Radio DJ Night Club and Lounge',
#     'location': {'address': '32 Avenue of the Americas',
#      'lat': 40.720443,
#      'lng': -74.005319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.720443,
#        'lng': -74.005319}],
#      'distance': 860,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32 Avenue of the Americas',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609285540',
#     'hasPerk': False},
#    {'id': '4e3e3828aeb73139a1846b2e',
#     'name': 'Ave night club',
#     'location': {'crossStreet': '116 10th Ave',
#      'lat': 40.7235273,
#      'lng': -73.997321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7235273,
#        'lng': -73.997321}],
#      'distance': 1408,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['116 10th Ave',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609285540',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-12-1cb4c0e6f6f4>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                    name  \
# 0  50db781be4b0ab9838c6963b      Shadow Night Clubs
# 1  4f77d6aee4b0e91fa757918b  Under the L Night Club
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11a941735', 'name': 'O...  v-1609282423    False
# 1  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609282423    False
#
#    location.address  location.lat  location.lng  \
# 0  All Over Chicago     41.878110    -87.629799
# 1               NaN     41.885571    -87.635139
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 41.87810998022422...                528
# 1  [{'label': 'display', 'lat': 41.88557099129635...               1424
#
#   location.postalCode location.cc location.city location.state  \
# 0               60632          US       Chicago             IL
# 1               60606          US       Chicago             IL
#
#   location.country                          location.formattedAddress
# 0    United States  [All Over Chicago, Chicago, IL 60632, United S...
# 1    United States                 [Chicago, IL 60606, United States]

# %%
dataframe.head(10)
# Out:
#                          id                    name  \
# 0  50db781be4b0ab9838c6963b      Shadow Night Clubs
# 1  4f77d6aee4b0e91fa757918b  Under the L Night Club
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11a941735', 'name': 'O...  v-1609282423    False
# 1  [{'id': '4bf58dd8d48988d11f941735', 'name': 'N...  v-1609282423    False
#
#    location.address  location.lat  location.lng  \
# 0  All Over Chicago     41.878110    -87.629799
# 1               NaN     41.885571    -87.635139
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 41.87810998022422...                528
# 1  [{'label': 'display', 'lat': 41.88557099129635...               1424
#
#   location.postalCode location.cc location.city location.state  \
# 0               60632          US       Chicago             IL
# 1               60606          US       Chicago             IL
#
#   location.country                          location.formattedAddress
# 0    United States  [All Over Chicago, Chicago, IL 60632, United S...
# 1    United States                 [Chicago, IL 60606, United States]

# %%
dataframe["location.lat"]
# Out:
# 0    41.878110
# 1    41.885571
# Name: location.lat, dtype: float64

# %%
for lat, lon, name in zip(dataframe["location.lat"],dataframe["location.lng"],dataframe["name"]):
    folium.CircleMarker(
    [lat,lon],
    radius=5,
    color='blue',
    popup=name,
    fill = True,
    fill_color='blue',
    fill_opacity=0.6,
    ).add_to(map_chicago)

# %%
map_chicago
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !conda install python=3 geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining clyent:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining requests:   0%|          | 1/316 [00:00<00:36,  8.62it/s]
# Examining requests:   1%|          | 2/316 [00:00<00:18, 17.24it/s]
# Examining imageio:   1%|          | 2/316 [00:00<00:18, 17.24it/s]
# Examining imageio:   1%|          | 3/316 [00:00<00:36,  8.60it/s]
# Examining pkginfo:   1%|          | 3/316 [00:01<00:36,  8.60it/s]
# Examining pkginfo:   1%|1         | 4/316 [00:01<01:59,  2.60it/s]
# Examining sphinxcontrib-jsmath:   1%|1         | 4/316 [00:01<01:59,  2.60it/s]
# Examining freetype:   2%|1         | 5/316 [00:01<01:59,  2.60it/s]
# Examining pytest:   2%|1         | 6/316 [00:01<01:59,  2.60it/s]
# Examining scikit-image:   2%|2         | 7/316 [00:04<01:58,  2.60it/s]
# Examining scikit-image:   3%|2         | 8/316 [00:04<02:36,  1.97it/s]
# Examining matplotlib:   3%|2         | 8/316 [00:06<02:36,  1.97it/s]
# Examining matplotlib:   3%|2         | 9/316 [00:06<05:21,  1.05s/it]
# Examining html5lib:   3%|2         | 9/316 [00:09<05:21,  1.05s/it]
# Examining html5lib:   3%|3         | 10/316 [00:09<07:24,  1.45s/it]
# Examining jinja2:   3%|3         | 10/316 [00:09<07:24,  1.45s/it]
# Examining zstd:   3%|3         | 11/316 [00:09<07:22,  1.45s/it]
# Examining zstd:   4%|3         | 12/316 [00:09<05:21,  1.06s/it]
# Examining setuptools:   4%|3         | 12/316 [00:09<05:21,  1.06s/it]
# Examining singledispatch:   4%|4         | 13/316 [00:10<05:20,  1.06s/it]
# Examining singledispatch:   4%|4         | 14/316 [00:10<04:08,  1.22it/s]
# Examining conda[version='>=4.9.2']:   4%|4         | 14/316 [00:10<04:08,  1.22it/s]
# Examining rtree:   5%|4         | 15/316 [00:10<04:07,  1.22it/s]
# Examining rtree:   5%|5         | 16/316 [00:10<03:00,  1.66it/s]
# Examining more-itertools:   5%|5         | 16/316 [00:10<03:00,  1.66it/s]
# Examining sortedcontainers:   5%|5         | 17/316 [00:10<02:59,  1.66it/s]
# Examining sphinxcontrib-devhelp:   6%|5         | 18/316 [00:10<02:59,  1.66it/s]
# Examining sphinxcontrib-devhelp:   6%|6         | 19/316 [00:10<02:09,  2.30it/s]
# Examining flask:   6%|6         | 19/316 [00:10<02:09,  2.30it/s]
# Examining pandas:   6%|6         | 20/316 [00:10<02:08,  2.30it/s]
# Examining parso:   7%|6         | 21/316 [00:12<02:08,  2.30it/s]
# Examining parso:   7%|6         | 22/316 [00:12<02:32,  1.93it/s]
# Examining pyopenssl:   7%|6         | 22/316 [00:12<02:32,  1.93it/s]
# Examining pyopenssl:   7%|7         | 23/316 [00:12<01:56,  2.52it/s]
# Examining itsdangerous:   7%|7         | 23/316 [00:12<01:56,  2.52it/s]
# Examining itsdangerous:   8%|7         | 24/316 [00:12<01:51,  2.63it/s]
# Examining sphinxcontrib-serializinghtml:   8%|7         | 24/316 [00:12<01:51,  2.63it/s]
# Examining tk:   8%|7         | 25/316 [00:13<01:50,  2.63it/s]
# Examining tk:   8%|8         | 26/316 [00:13<01:27,  3.30it/s]
# Examining tornado:  95%|#########5| 301/316 [01:58<00:03,  4.76it/s]
# Examining nltk:  96%|#########5| 302/316 [01:58<00:02,  4.76it/s]
# Examining nltk:  96%|#########5| 303/316 [01:58<00:02,  6.13it/s]
# Examining boto:  96%|#########5| 303/316 [01:58<00:02,  6.13it/s]
# Examining sphinxcontrib-applehelp:  96%|#########6| 304/316 [01:58<00:01,  6.13it/s]
# Examining sphinxcontrib-applehelp:  97%|#########6| 305/316 [01:58<00:01,  6.30it/s]
# Examining py-lief:  97%|#########6| 305/316 [01:58<00:01,  6.30it/s]
# Examining krb5:  97%|#########6| 306/316 [01:58<00:01,  6.30it/s]
# Examining libssh2:  97%|#########7| 307/316 [01:58<00:01,  6.30it/s]
# Examining beautifulsoup4:  97%|#########7| 308/316 [01:58<00:01,  6.30it/s]
# Examining pathlib2:  98%|#########7| 309/316 [01:59<00:01,  6.30it/s]
# Examining pathlib2:  98%|#########8| 310/316 [01:59<00:00,  8.33it/s]
# Examining pytz:  98%|#########8| 310/316 [01:59<00:00,  8.33it/s]
# Examining bitarray:  98%|#########8| 311/316 [01:59<00:00,  8.33it/s]
# Examining bitarray:  99%|#########8| 312/316 [01:59<00:00,  9.79it/s]
# Examining xlsxwriter:  99%|#########8| 312/316 [01:59<00:00,  9.79it/s]
# Examining lxml:  99%|#########9| 313/316 [01:59<00:00,  9.79it/s]
# Examining lxml:  99%|#########9| 314/316 [01:59<00:00,  9.30it/s]
# Examining conda-verify:  99%|#########9| 314/316 [01:59<00:00,  9.30it/s]
# Examining pywin32-ctypes: 100%|#########9| 315/316 [01:59<00:00,  9.30it/s]
# Examining pywin32-ctypes: 100%|##########| 316/316 [01:59<00:00,  7.89it/s]
#
#
# Determining conflicts:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining conflict for anaconda-client anaconda-navigator clyent anaconda-project anaconda:   0%|          | 0/316 [00:00<?, ?it/s]
# Examining conflict for clyent markupsafe path.py requests folium sphinxcontrib-htmlhelp decorator zope.interface imageio pkginfo sphinxcontrib-qthelp conda-build sphinxcontrib-jsmath nbformat entrypoints xlwings argh ipython_genutils msgpack-python distributed bcrypt intervaltree mock pytest scikit-image matplotlib nose html5lib olefile jinja2 argon2-cffi zope.event click multipledispatch python-language-server pip pyzmq bkcharts pyqt send2trash mkl-service zict setuptools singledispatch python-jsonrpc-server conda defusedxml nbclient idna py pyrsistent jupyterlab rtree pyyaml mkl_fft numpy more-itertools prometheus_client numpy-base pyflakes psutil certifi xlrd notebook iniconfig backcall sortedcontainers sphinxcontrib-devhelp brotlipy typing_extensions pywin32-ctypes flask watchdog python_abi numba heapdict packaging cython cytoolz patsy partd backports console_shortcut six networkx wheel pandas wrapt astropy importlib_metadata parso pyopenssl _ipyw_jlab_nb_ext_conf itsdangerous atomicwrites sphinxcontrib-serializinghtml sqlalchemy async_generator keyring pywinpty terminado geopy wincertstore nest-asyncio anaconda-project glob2 sphinxcontrib-websupport toolz backports.functools_lru_cache jedi spyder cryptography pycosat comtypes imagesize soupsieve jupyter openpyxl tblib pysocks python-dateutil scikit-learn bleach qdarkstyle locket threadpoolctl jsonschema jupyter_core sip dask et_xmlfile webencodings pydocstyle attrs sphinxcontrib backports.tempfile anaconda prompt_toolkit jupyterlab_server bottleneck pandocfilters urllib3 yapf seaborn tqdm nbconvert pycodestyle xlwt matplotlib-base get_terminal_size kiwisolver python-libarchive-c widgetsnbextension pycurl alabaster isort spyder-kernels asn1crypto xmltodict unicodecsv zope backports.shutil_get_terminal_size qtpy cffi ipykernel rope pylint win_unicode_console fastcache gevent pillow zipp jupyter_client numexpr ipython sympy scipy pep8 pathtools qtawesome ruamel_yaml testpath lazy-object-proxy paramiko anaconda-navigator geopandas filelock statsmodels flake8 pickleshare prompt-toolkit menuinst backports.weakref autopep8 snowballstemmer babel pygments numpydoc bokeh pyreadline pexpect json5 importlib-metadata cycler dask-core powershell_shortcut mkl_random colorama pyodbc win_inet_pton regex ujson conda-package-handling ipywidgets sortedcollections pywin32 tifffile anaconda-client fsspec pynacl jupyter_console joblib pyparsing pycparser jupyterlab_pygments astroid contextlib2 path werkzeug mistune tornado nltk boto wcwidth sphinxcontrib-applehelp llvmlite py-lief pytables mpmath mccabe simplegeneric cloudpickle beautifulsoup4 sphinx pathlib2 pytz geographiclib h5py branca pywavelets traitlets bitarray ply docutils jdcal qtconsole pluggy xlsxwriter toml lxml navigator-updater conda-verify greenlet future chardet diff-match-patch python:   0%|          | 1/316 [00:03<19:23,  3.69s/it]
# Examining conflict for clyent markupsafe path.py requests folium sphinxcontrib-htmlhelp decorator zope.interface imageio pkginfo sphinxcontrib-qthelp conda-build sphinxcontrib-jsmath nbformat entrypoints xlwings argh ipython_genutils msgpack-python distributed bcrypt intervaltree mock pytest scikit-image matplotlib nose html5lib olefile jinja2 argon2-cffi zope.event click multipledispatch python-language-server pip pyzmq bkcharts pyqt send2trash mkl-service zict setuptools singledispatch python-jsonrpc-server conda defusedxml nbclient idna py pyrsistent jupyterlab rtree pyyaml mkl_fft numpy more-itertools prometheus_client numpy-base pyflakes psutil certifi xlrd notebook iniconfig backcall sortedcontainers sphinxcontrib-devhelp brotlipy typing_extensions pywin32-ctypes flask watchdog python_abi numba heapdict packaging cython cytoolz patsy partd backports console_shortcut six networkx wheel pandas wrapt astropy importlib_metadata parso pyopenssl _ipyw_jlab_nb_ext_conf itsdangerous atomicwrites sphinxcontrib-serializinghtml sqlalchemy async_generator keyring pywinpty terminado geopy wincertstore nest-asyncio anaconda-project glob2 sphinxcontrib-websupport toolz backports.functools_lru_cache jedi spyder cryptography pycosat comtypes imagesize soupsieve jupyter openpyxl tblib pysocks python-dateutil scikit-learn bleach qdarkstyle locket threadpoolctl jsonschema jupyter_core sip dask et_xmlfile webencodings pydocstyle attrs sphinxcontrib backports.tempfile anaconda prompt_toolkit jupyterlab_server bottleneck pandocfilters urllib3 yapf seaborn tqdm nbconvert pycodestyle xlwt matplotlib-base get_terminal_size kiwisolver python-libarchive-c widgetsnbextension pycurl alabaster isort spyder-kernels asn1crypto xmltodict unicodecsv zope backports.shutil_get_terminal_size qtpy cffi ipykernel rope pylint win_unicode_console fastcache gevent pillow zipp jupyter_client numexpr ipython sympy scipy pep8 pathtools qtawesome ruamel_yaml testpath lazy-object-proxy paramiko anaconda-navigator geopandas filelock statsmodels flake8 pickleshare prompt-toolkit menuinst backports.weakref autopep8 snowballstemmer babel pygments numpydoc bokeh pyreadline pexpect json5 importlib-metadata cycler dask-core powershell_shortcut mkl_random colorama pyodbc win_inet_pton regex ujson conda-package-handling ipywidgets sortedcollections pywin32 tifffile anaconda-client fsspec pynacl jupyter_console joblib pyparsing pycparser jupyterlab_pygments astroid contextlib2 path werkzeug mistune tornado nltk boto wcwidth sphinxcontrib-applehelp llvmlite py-lief pytables mpmath mccabe simplegeneric cloudpickle beautifulsoup4 sphinx pathlib2 pytz geographiclib h5py branca pywavelets traitlets bitarray ply docutils jdcal qtconsole pluggy xlsxwriter toml lxml navigator-updater conda-verify greenlet future chardet diff-match-patch python:   1%|          | 2/316 [00:03<09:39,  1.85s/it]
# Examining conflict for clyent markupsafe path.py requests folium sphinxcontrib-htmlhelp decorator zope.interface imageio pkginfo sphinxcontrib-qthelp conda-build sphinxcontrib-jsmath nbformat entrypoints xlwings argh ipython_genutils msgpack-python distributed bcrypt intervaltree mock pytest scikit-image matplotlib nose html5lib olefile jinja2 argon2-cffi zope.event click multipledispatch libcurl qt python-language-server pip pyzmq bkcharts pyqt send2trash mkl-service zict setuptools singledispatch python-jsonrpc-server conda defusedxml nbclient idna py pyrsistent jupyterlab rtree pyyaml mkl_fft numpy more-itertools prometheus_client numpy-base pyflakes psutil certifi xlrd notebook iniconfig backcall sortedcontainers sphinxcontrib-devhelp brotlipy typing_extensions pywin32-ctypes flask watchdog python_abi numba heapdict packaging cython cytoolz patsy partd backports console_shortcut six networkx wheel pandas wrapt astropy importlib_metadata parso pyopenssl _ipyw_jlab_nb_ext_conf itsdangerous atomicwrites sphinxcontrib-serializinghtml openssl async_generator sqlalchemy keyring pywinpty terminado wincertstore geopy nest-asyncio anaconda-project glob2 sphinxcontrib-websupport toolz backports.functools_lru_cache jedi spyder cryptography pycosat comtypes imagesize soupsieve jupyter openpyxl tblib pysocks python-dateutil scikit-learn bleach qdarkstyle locket threadpoolctl jsonschema jupyter_core sip dask et_xmlfile webencodings pydocstyle attrs sphinxcontrib backports.tempfile anaconda prompt_toolkit jupyterlab_server bottleneck pandocfilters urllib3 yapf seaborn tqdm nbconvert pycodestyle xlwt matplotlib-base kiwisolver python-libarchive-c widgetsnbextension pycurl alabaster isort spyder-kernels libarchive xmltodict asn1crypto unicodecsv zope backports.shutil_get_terminal_size qtpy cffi ipykernel rope pylint win_unicode_console fastcache gevent pillow zipp jupyter_client numexpr ipython sympy scipy pep8 pathtools qtawesome ruamel_yaml testpath lazy-object-proxy paramiko anaconda-navigator geopandas filelock statsmodels curl flake8 pickleshare prompt-toolkit menuinst backports.weakref autopep8 snowballstemmer babel pygments numpydoc bokeh pyreadline pexpect json5 importlib-metadata cycler dask-core powershell_shortcut mkl_random colorama pyodbc win_inet_pton regex ujson conda-package-handling ipywidgets sortedcollections pywin32 tifffile anaconda-client fsspec pynacl jupyter_console joblib pyparsing pycparser jupyterlab_pygments astroid contextlib2 path werkzeug mistune tornado nltk boto wcwidth sphinxcontrib-applehelp llvmlite py-lief pytables krb5 mpmath libssh2 mccabe simplegeneric cloudpickle beautifulsoup4 sphinx pathlib2 pytz geographiclib h5py branca pywavelets traitlets bitarray ply docutils jdcal qtconsole pluggy xlsxwriter toml lxml navigator-updater conda-verify greenlet future chardet diff-match-patch python:   1%|          | 2/316 [00:20<09:39,  1.85s/it]
# Examining conflict for clyent markupsafe path.py requests folium sphinxcontrib-htmlhelp decorator zope.interface imageio pkginfo sphinxcontrib-qthelp conda-build sphinxcontrib-jsmath nbformat entrypoints xlwings argh ipython_genutils msgpack-python distributed bcrypt intervaltree mock pytest scikit-image matplotlib nose html5lib olefile jinja2 argon2-cffi zope.event click multipledispatch libcurl qt python-language-server pip pyzmq bkcharts pyqt send2trash mkl-service zict setuptools singledispatch python-jsonrpc-server conda defusedxml nbclient idna py pyrsistent jupyterlab rtree pyyaml mkl_fft numpy more-itertools prometheus_client numpy-base pyflakes psutil certifi xlrd notebook iniconfig backcall sortedcontainers sphinxcontrib-devhelp brotlipy typing_extensions pywin32-ctypes flask watchdog python_abi numba heapdict packaging cython cytoolz patsy partd backports console_shortcut six networkx wheel pandas wrapt astropy importlib_metadata parso pyopenssl _ipyw_jlab_nb_ext_conf itsdangerous atomicwrites sphinxcontrib-serializinghtml openssl async_generator sqlalchemy keyring pywinpty terminado wincertstore geopy nest-asyncio anaconda-project glob2 sphinxcontrib-websupport toolz backports.functools_lru_cache jedi spyder cryptography pycosat comtypes imagesize soupsieve jupyter openpyxl tblib pysocks python-dateutil scikit-learn bleach qdarkstyle locket threadpoolctl jsonschema jupyter_core sip dask et_xmlfile webencodings pydocstyle attrs sphinxcontrib backports.tempfile anaconda prompt_toolkit jupyterlab_server bottleneck pandocfilters urllib3 yapf seaborn tqdm nbconvert pycodestyle xlwt matplotlib-base kiwisolver python-libarchive-c widgetsnbextension pycurl alabaster isort spyder-kernels libarchive xmltodict asn1crypto unicodecsv zope backports.shutil_get_terminal_size qtpy cffi ipykernel rope pylint win_unicode_console fastcache gevent pillow zipp jupyter_client numexpr ipython sympy scipy pep8 pathtools qtawesome ruamel_yaml testpath lazy-object-proxy paramiko anaconda-navigator geopandas filelock statsmodels curl flake8 pickleshare prompt-toolkit menuinst backports.weakref autopep8 snowballstemmer babel pygments numpydoc bokeh pyreadline pexpect json5 importlib-metadata cycler dask-core powershell_shortcut mkl_random colorama pyodbc win_inet_pton regex ujson conda-package-handling ipywidgets sortedcollections pywin32 tifffile anaconda-client fsspec pynacl jupyter_console joblib pyparsing pycparser jupyterlab_pygments astroid contextlib2 path werkzeug mistune tornado nltk boto wcwidth sphinxcontrib-applehelp llvmlite py-lief pytables krb5 mpmath libssh2 mccabe simplegeneric cloudpickle beautifulsoup4 sphinx pathlib2 pytz geographiclib h5py branca pywavelets traitlets bitarray ply docutils jdcal qtconsole pluggy xlsxwriter toml lxml navigator-updater conda-verify greenlet future chardet diff-match-patch python:   1%|          | 3/316 [00:20<33:26,  6.41s/it]
# Examining conflict for clyent markupsafe path.py requests folium sphinxcontrib-htmlhelp decorator zope.interface imageio vc pkginfo sphinxcontrib-qthelp conda-build sphinxcontrib-jsmath nbformat entrypoints xlwings argh ipython_genutils msgpack-python distributed bcrypt intervaltree freetype libspatialindex liblief mock pytest scikit-image matplotlib nose html5lib olefile jinja2 argon2-cffi zope.event click multipledispatch libcurl qt python-language-server pip pyzmq bkcharts lz4-c pyqt zstd send2trash blosc mkl-service zict setuptools singledispatch python-jsonrpc-server conda defusedxml nbclient idna py pyrsistent jupyterlab rtree pyyaml mkl_fft numpy more-itertools prometheus_client numpy-base pyflakes psutil certifi xlrd notebook iniconfig backcall sortedcontainers sphinxcontrib-devhelp brotlipy typing_extensions zeromq pywin32-ctypes flask watchdog python_abi numba heapdict packaging cython cytoolz yaml patsy partd backports console_shortcut six networkx wheel pandas wrapt astropy hdf5 importlib_metadata parso pyopenssl _ipyw_jlab_nb_ext_conf itsdangerous atomicwrites sphinxcontrib-serializinghtml openssl async_generator sqlalchemy keyring pywinpty terminado wincertstore geopy nest-asyncio zlib anaconda-project glob2 sphinxcontrib-websupport toolz backports.functools_lru_cache winpty tk libsodium jedi spyder cryptography pycosat comtypes imagesize soupsieve jupyter libtiff openpyxl tblib pysocks python-dateutil scikit-learn bleach libxml2 jpeg qdarkstyle sqlite locket threadpoolctl jsonschema jupyter_core sip dask et_xmlfile webencodings pydocstyle attrs sphinxcontrib libiconv backports.tempfile anaconda prompt_toolkit jupyterlab_server bottleneck pandocfilters urllib3 yapf seaborn tqdm nbconvert pycodestyle xlwt matplotlib-base kiwisolver python-libarchive-c widgetsnbextension pycurl alabaster isort spyder-kernels libarchive xmltodict asn1crypto unicodecsv libxslt zope backports.shutil_get_terminal_size qtpy cffi ipykernel rope pylint win_unicode_console fastcache gevent pillow zipp jupyter_client numexpr ipython sympy scipy pep8 pathtools qtawesome ruamel_yaml testpath lazy-object-proxy paramiko anaconda-navigator geopandas filelock icu statsmodels curl xz bzip2 pickleshare prompt-toolkit flake8 menuinst backports.weakref autopep8 snowballstemmer babel pygments numpydoc bokeh pyreadline lzo pexpect json5 importlib-metadata cycler dask-core powershell_shortcut mkl_random colorama libpng pyodbc win_inet_pton regex ujson conda-package-handling ipywidgets sortedcollections pywin32 tifffile anaconda-client fsspec pynacl jupyter_console joblib pyparsing pycparser jupyterlab_pygments astroid contextlib2 path werkzeug mistune tornado nltk boto wcwidth sphinxcontrib-applehelp llvmlite py-lief pytables krb5 mpmath libssh2 mccabe simplegeneric cloudpickle beautifulsoup4 sphinx pathlib2 pytz geographiclib h5py branca pywavelets traitlets bitarray ply docutils jdcal qtconsole pluggy xlsxwriter toml lxml navigator-updater conda-verify greenlet future chardet diff-match-patch python:   1%|          | 3/316 [00:37<33:26,  6.41s/it]
# ...
# seaborn -> matplotlib[version='>=1.4.3|>=2.1.2']
# scikit-image -> matplotlib[version='>=1.3.1|>=2.0.0']
# bokeh -> matplotlib
# anaconda==2020.11 -> seaborn==0.11.0=py_0 -> matplotlib[version='>=2.1.2']
# nltk -> matplotlib
# geopandas -> matplotlib
#
# Package tifffile conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26']
# anaconda==2020.11 -> scikit-image==0.17.2=py37h1e1f486_0 -> tifffile[version='>=2019.7.26']
# anaconda==2020.11 -> tifffile==2020.10.1[build='py37h8c2d366_2|py38h8c2d366_2']
# tifffile
#
# Package pywin32-ctypes conflicts for:
# spyder -> keyring[version='>=17.0.0'] -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# anaconda==2020.11 -> pywin32-ctypes==0.2.0[build='py38_1000|py37_1001']
# anaconda==2020.11 -> keyring==21.4.0=py37_1 -> pywin32-ctypes
# pywin32-ctypes
#
# Package sortedcontainers conflicts for:
# sortedcontainers
# sortedcollections -> sortedcontainers[version='>=2.0']
# attrs -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# dask -> distributed[version='>=2020.12.0'] -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# anaconda==2020.11 -> distributed==2.30.1=py37haa95532_0 -> sortedcontainers[version='!=2.0.0,!=2.0.1|>=2.0']
# intervaltree -> sortedcontainers
# anaconda==2020.11 -> sortedcontainers==2.2.2=py_0
# distributed -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# spyder -> intervaltree[version='>=3.0.2'] -> sortedcontainers
#
# Package sphinxcontrib-serializinghtml conflicts for:
# sphinx -> sphinxcontrib-serializinghtml
# numpydoc -> sphinx -> sphinxcontrib-serializinghtml
# sphinxcontrib-serializinghtml
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> sphinxcontrib-serializinghtml
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-serializinghtml
# anaconda==2020.11 -> sphinxcontrib-serializinghtml==1.1.4=py_0
#
# Package xlwt conflicts for:
# xlwt
# anaconda==2020.11 -> xlwt==1.3.0[build='py38_0|py37_0']
#
# Package sympy conflicts for:
# sympy
# anaconda==2020.11 -> sympy==1.6.2[build='py37haa95532_1|py38haa95532_1']
#
# Package libcurl conflicts for:
# libcurl
# anaconda==2020.11 -> pycurl==7.43.0.6=py37h7a1dbc1_0 -> libcurl[version='>=7.71.1,<8.0a0']
# pycurl -> libcurl[version='>=7.60.0,<8.0a0|>=7.61.0,<8.0a0|>=7.63.0,<8.0a0|>=7.64.1,<8.0a0|>=7.65.3,<8.0a0|>=7.67.0,<8.0a0|>=7.71.1,<8.0a0']
# pycurl -> curl[version='>=7.55.1,<8.0a0'] -> libcurl[version='7.57.0|7.58.0|7.58.0|7.59.0|7.59.0|7.60.0|7.60.0|7.61.0|7.61.0|7.61.1|7.61.1|7.61.1|7.62.0|7.62.0|7.63.0|7.63.0|7.63.0|7.63.0|7.64.0|7.64.0|7.64.1|7.64.1|7.65.2|7.65.2|7.65.3|7.65.3|7.67.0|7.68.0|7.69.1|7.71.0|7.71.1',build='h7a46e7a_0|h7a46e7a_0|h7602738_0|h0990ea7_0|hc4dcbb0_0|hc4dcbb0_0|h0990ea7_0|h7a46e7a_0|h7602738_0|h7602738_0|h7a46e7a_0|h7a46e7a_0|h7a46e7a_0|h7a46e7a_1000|h2a8f88b_2|h7a46e7a_0|h7a46e7a_0|h7a46e7a_0|h2a8f88b_1|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h7a46e7a_2|h2a8f88b_1000|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0']
# anaconda==2020.11 -> libcurl==7.71.1=h2a8f88b_1
# curl -> libcurl[version='7.57.0|7.58.0|7.58.0|7.59.0|7.59.0|7.60.0|7.60.0|7.61.0|7.61.0|7.61.1|7.61.1|7.61.1|7.62.0|7.62.0|7.63.0|7.63.0|7.63.0|7.63.0|7.64.0|7.64.0|7.64.1|7.64.1|7.65.2|7.65.2|7.65.3|7.65.3|7.67.0|7.68.0|7.69.1|7.71.0|7.71.1',build='h7a46e7a_0|h7a46e7a_0|h7602738_0|h0990ea7_0|hc4dcbb0_0|hc4dcbb0_0|h0990ea7_0|h7a46e7a_0|h7602738_0|h7602738_0|h7a46e7a_0|h7a46e7a_0|h7a46e7a_0|h7a46e7a_1000|h2a8f88b_2|h7a46e7a_0|h7a46e7a_0|h7a46e7a_0|h2a8f88b_1|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0|h7a46e7a_2|h2a8f88b_1000|h2a8f88b_0|h2a8f88b_0|h2a8f88b_0']
#
# Package branca conflicts for:
# folium -> branca[version='>=0.3.0']
# branca
#
# Package zope.event conflicts for:
# zope.event
# anaconda==2020.11 -> zope.event==4.5.0[build='py38_0|py37_0']
# anaconda==2020.11 -> gevent==20.9.0=py37he774522_0 -> zope.event
# gevent -> zope.event
#
# Package pandoc conflicts for:
# anaconda==2020.11 -> pandoc==2.11=h9490d1a_0
# pandoc
# notebook -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# jupyter -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# spyder -> nbconvert[version='>=4.0'] -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# anaconda==2020.11 -> nbconvert==6.0.7=py37_0 -> pandoc[version='>=1.12.1']
#
# Package alabaster conflicts for:
# spyder -> sphinx[version='>=0.6.6'] -> alabaster[version='>=0.7,<0.8']
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> alabaster[version='>=0.7,<0.8']
# alabaster
# numpydoc -> sphinx -> alabaster[version='>=0.7,<0.8']
# sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2020.11 -> alabaster==0.7.12[build='py37_0|py_0']
#
# Package libspatialindex conflicts for:
# spyder -> rtree[version='>=0.8.3'] -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# geopandas -> rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2020.11 -> libspatialindex==1.9.3=h33f27b4_0
# anaconda==2020.11 -> rtree==0.9.4=py37h21ff451_1 -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# libspatialindex
#
# Package docutils conflicts for:
# anaconda==2020.11 -> docutils==0.16[build='py37_1|py38_1']
# anaconda==2020.11 -> sphinx==3.2.1=py_0 -> docutils[version='>=0.12']
# sphinx -> docutils[version='>=0.11|>=0.12']
# numpydoc -> sphinx -> docutils[version='>=0.11|>=0.12']
# docutils
# spyder -> sphinx[version='>=0.6.6'] -> docutils[version='>=0.11|>=0.12']
#
# Package cython conflicts for:
# anaconda==2020.11 -> cython==0.29.21[build='py38ha925a31_0|py37ha925a31_0']
# cython
#
# Package soupsieve conflicts for:
# anaconda==2020.11 -> soupsieve==2.0.1=py_0
# beautifulsoup4 -> soupsieve[version='>=1.2']
# conda-build -> beautifulsoup4 -> soupsieve[version='>=1.2']
# soupsieve
# anaconda==2020.11 -> beautifulsoup4==4.9.3=pyhb0f4dca_0 -> soupsieve[version='>=1.2']
#
# Package filelock conflicts for:
# filelock
# conda-build -> filelock
# anaconda==2020.11 -> filelock==3.0.12=py_0
#
# Package krb5 conflicts for:
# anaconda==2020.11 -> krb5==1.18.2=hc04afaa_0
# anaconda==2020.11 -> curl==7.71.1=h2a8f88b_1 -> krb5[version='>=1.18.2,<1.19.0a0']
# krb5
# pycurl -> libcurl[version='>=7.71.1,<8.0a0'] -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# curl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
# libcurl -> krb5[version='>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.18.2,<1.19.0a0']
#
# Package regex conflicts for:
# regex
# anaconda==2020.11 -> nltk==3.5=py_0 -> regex
# nltk -> regex
# anaconda==2020.11 -> regex==2020.10.15[build='py37he774522_0|py38he774522_0']
#
# Package bottleneck conflicts for:
# anaconda==2020.11 -> bottleneck==1.3.2[build='py38h2a96729_1|py37h2a96729_1']
# bottleneck
#
# Package sqlalchemy conflicts for:
# sqlalchemy
# geopandas -> sqlalchemy
# anaconda==2020.11 -> sqlalchemy==1.3.20[build='py37h2bbff1b_0|py38h2bbff1b_0']
#
# Package qtconsole conflicts for:
# qtconsole
# anaconda==2020.11 -> qtconsole==4.7.7=py_0
# spyder -> qtconsole[version='>=4.2|>=4.6.0|>=4.7.7']
# jupyter -> qtconsole
# anaconda==2020.11 -> jupyter==1.0.0=py37_7 -> qtconsole[version='>=4.6.0']
#
# Package pyodbc conflicts for:
# pyodbc
# anaconda==2020.11 -> pyodbc==4.0.30[build='py38ha925a31_0|py37ha925a31_0']
#
# Package prometheus_client conflicts for:
# anaconda==2020.11 -> prometheus_client==0.8.0=py_0
# widgetsnbextension -> notebook[version='>=4.4.1'] -> prometheus_client
# anaconda==2020.11 -> notebook==6.1.4=py37_0 -> prometheus_client
# jupyter -> notebook -> prometheus_client
# notebook -> prometheus_client
# jupyterlab_server -> notebook[version='>=4.2.0'] -> prometheus_client
# jupyterlab -> notebook[version='>=4.3.1'] -> prometheus_client
# prometheus_client
#
# Package distributed conflicts for:
# dask -> distributed[version='>=1.16.0|>=1.19.0|>=1.20.0|>=1.21.0|>=1.22.0|>=1.23.0|>=1.23.1|>=1.23.2|>=1.23.3|>=1.24.2|>=1.25.0|>=1.25.3|>=1.26.0|>=1.26.1|>=1.27.0|>=1.28.0|>=2|>=2.10.0|>=2.11.0|>=2.12.0|>=2.13.0|>=2.14.0|>=2.15.0|>=2.16.0|>=2.17.0|>=2.18.0|>=2.19.0|>=2.20.0|>=2.22.0|>=2.23.0|>=2.24.0|>=2.25.0|>=2.26.0|>=2.27.0|>=2.29.0|>=2.30.0|>=2020.12.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=1.21.1']
# scikit-image -> dask[version='>=0.5'] -> distributed[version='>=1.16.0|>=1.19.0|>=1.20.0|>=1.21.0|>=1.22.0|>=1.23.0|>=1.23.1|>=1.23.2|>=1.23.3|>=1.24.2|>=1.25.0|>=1.25.3|>=1.26.0|>=1.26.1|>=1.27.0|>=1.28.0|>=2|>=2.10.0|>=2.11.0|>=2.12.0|>=2.13.0|>=2.14.0|>=2.15.0|>=2.16.0|>=2.17.0|>=2.18.0|>=2.19.0|>=2.20.0|>=2.22.0|>=2.23.0|>=2.24.0|>=2.25.0|>=2.26.0|>=2.27.0|>=2.29.0|>=2.30.0|>=2020.12.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=1.21.1']
# anaconda==2020.11 -> distributed==2.30.1[build='py37haa95532_0|py38haa95532_0']
# distributed
# anaconda==2020.11 -> dask==2.30.0=py_0 -> distributed[version='>=2.30.0']
#
# Package jupyterlab_launcher conflicts for:
# jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
#
# Package pathtools conflicts for:
# anaconda==2020.11 -> pathtools==0.1.2=py_1
# pathtools
# anaconda==2020.11 -> watchdog==0.10.3=py37_0 -> pathtools[version='>=0.1.1']
# watchdog -> pathtools[version='>=0.1.1']
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
#
# Package pysocks conflicts for:
# anaconda==2020.11 -> urllib3==1.25.11=py_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks
# anaconda==2020.11 -> pysocks==1.7.1[build='py37_1|py38_0']
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package nose conflicts for:
# anaconda==2020.11 -> nose==1.3.7[build='py37_1004|py38_2']
# nose
#
# Package iniconfig conflicts for:
# iniconfig
# anaconda==2020.11 -> iniconfig==1.1.1=py_0
# pytest -> iniconfig
# astropy -> pytest -> iniconfig
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> iniconfig
#
# Package pexpect conflicts for:
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> pexpect[version='>=4.4.0']
# spyder -> pexpect[version='>=4.4.0']
# pexpect
# anaconda==2020.11 -> pexpect==4.8.0[build='py37_1|py38_0']
#
# Package snappy conflicts for:
# tifffile -> imagecodecs -> snappy[version='>=1.1.8,<2.0a0']
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# pytables -> blosc[version='>=1.16.3,<2.0a0'] -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
#
# Package unicodecsv conflicts for:
# unicodecsv
# anaconda==2020.11 -> unicodecsv==0.14.1[build='py38_0|py37_0']
#
# Package _low_priority conflicts for:
# libarchive -> _low_priority
# python-libarchive-c -> libarchive -> _low_priority
# conda-build -> libarchive -> _low_priority
#
# Package qtawesome conflicts for:
# qtawesome
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> qtawesome[version='>=0.5.7']
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7']
# anaconda==2020.11 -> qtawesome==1.0.1=py_0
#
# Package atomicwrites conflicts for:
# atomicwrites
# anaconda==2020.11 -> pytest==6.1.1=py37_0 -> atomicwrites[version='>=1.0|>=1.2.0']
# astropy -> pytest[version='<4'] -> atomicwrites[version='>=1.0']
# pytest -> atomicwrites[version='>=1.0']
# anaconda==2020.11 -> atomicwrites==1.4.0=py_0
# spyder -> atomicwrites[version='>=1.2.0']
#
# Package toolz conflicts for:
# dask -> toolz[version='>=0.7.3|>=0.8.2']
# anaconda==2020.11 -> cytoolz==0.11.0=py37he774522_0 -> toolz[version='>=0.10.0|>=0.8.2|>=0.7.3']
# dask -> cytoolz[version='>=0.8.2'] -> toolz[version='>=0.10.0|>=0.8.0|>=0.7.4']
# distributed -> toolz[version='>=0.7.4|>=0.8.2']
# anaconda==2020.11 -> toolz==0.11.1=py_0
# distributed -> cytoolz[version='>=0.8.2'] -> toolz[version='>=0.10.0|>=0.8.0']
# scikit-image -> cytoolz[version='>=0.7.3'] -> toolz[version='>=0.10.0|>=0.8.0|>=0.8.2']
# partd -> toolz
# toolz
# scikit-image -> toolz[version='>=0.7.3|>=0.7.4']
# cytoolz -> toolz[version='>=0.10.0|>=0.8.0']
#
# Package intervaltree conflicts for:
# anaconda==2020.11 -> intervaltree==3.1.0=py_0
# spyder -> intervaltree[version='>=3.0.2']
# intervaltree
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> intervaltree
#
# Package conda-env conflicts for:
# conda-env
# conda-build -> conda[version='>=4.5'] -> conda-env[version='>=2.6']
#
# Package mock conflicts for:
# anaconda==2020.11 -> pytables==3.6.1=py37h1da0976_0 -> mock
# pytables -> mock
# anaconda==2020.11 -> mock==4.0.2=py_0
# mock
#
# Package ptyprocess conflicts for:
# pexpect -> ptyprocess[version='>=0.5']
# spyder -> pexpect[version='>=4.4.0'] -> ptyprocess[version='>=0.5']
#
# Package boto conflicts for:
# boto
# anaconda==2020.11 -> boto==2.49.0[build='py38_0|py37_0']
#
# Package sortedcollections conflicts for:
# anaconda==2020.11 -> sortedcollections==1.2.1=py_0
# sortedcollections
#
# Package nltk conflicts for:
# nltk
# anaconda==2020.11 -> nltk==3.5=py_0
#
# Package astropy conflicts for:
# astropy
# anaconda==2020.11 -> astropy==4.0.2[build='py37he774522_0|py38he774522_0']
#
# Package distlib conflicts for:
# bcrypt -> pip -> distlib
# pip -> distlib
# python=3 -> pip -> distlib
#
# Package spyder-kernels conflicts for:
# anaconda==2020.11 -> spyder-kernels==1.9.4[build='py38_0|py37_0']
# spyder-kernels
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2020.11 -> spyder==4.1.5=py37_0 -> spyder-kernels[version='>=1.9.4,<1.10.0']
#
# Package liblief conflicts for:
# conda-build -> py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_0|hd77b12b_1|ha925a31_3|ha925a31_2']
# liblief
# py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_0|hd77b12b_1|ha925a31_3|ha925a31_2']
# anaconda==2020.11 -> liblief==0.10.1=ha925a31_0
#
# Package xmltodict conflicts for:
# anaconda-navigator -> xmltodict
# xmltodict
#
# Package conda-package-handling conflicts for:
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-package-handling
# conda[version='>=4.9.2'] -> conda-package-handling[version='>=1.3.0']
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
#
# Package lxml conflicts for:
# anaconda==2020.11 -> lxml==4.6.1[build='py37h1350720_0|py38h1350720_0']
# lxml
#
# Package xlwings conflicts for:
# xlwings
# anaconda==2020.11 -> xlwings==0.20.8[build='py38_0|py37_0']
#
# Package gevent conflicts for:
# anaconda==2020.11 -> gevent==20.9.0[build='py37he774522_0|py38he774522_0']
# gevent
#
# Package autopep8 conflicts for:
# autopep8
# anaconda==2020.11 -> python-language-server==0.35.1=py_0 -> autopep8
# python-language-server -> autopep8
# anaconda==2020.11 -> autopep8==1.5.4=py_0
# spyder -> python-language-server[version='>=0.36.1,<1.0.0'] -> autopep8
#
# Package xlsxwriter conflicts for:
# xlsxwriter
# anaconda==2020.11 -> xlsxwriter==1.3.7=py_0
#
# Package locket conflicts for:
# locket
# anaconda==2020.11 -> partd==1.1.0=py_0 -> locket
# partd -> locket
# anaconda==2020.11 -> locket==0.2.0[build='py37_1|py38_1']
# dask -> partd[version='>=0.3.10'] -> locket
#
# Package jdcal conflicts for:
# openpyxl -> jdcal
# jdcal
# anaconda==2020.11 -> jdcal==1.4.1=py_0
# anaconda==2020.11 -> openpyxl==3.0.5=py_0 -> jdcal
#
# Package navigator-updater conflicts for:
# anaconda-navigator -> navigator-updater
# navigator-updater
#
# Package contextvars conflicts for:
# dask -> distributed[version='>=2020.12.0'] -> contextvars
# distributed -> contextvars
#
# Package libllvm9 conflicts for:
# numba -> llvmlite[version='>=0.33.0'] -> libllvm9
# llvmlite -> libllvm9
#
# Package scikit-image conflicts for:
# scikit-image
# anaconda==2020.11 -> scikit-image==0.17.2[build='py37h1e1f486_0|py38h1e1f486_0']
#
# Package imagecodecs conflicts for:
# scikit-image -> tifffile[version='>=2019.7.26'] -> imagecodecs
# tifffile -> imagecodecs
#
# Package hypothesis conflicts for:
# astropy -> pytest-astropy -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
# attrs -> hypothesis
#
# Package jupyter conflicts for:
# anaconda==2020.11 -> jupyter==1.0.0[build='py38_7|py37_7']
# jupyter
#
# Package flask conflicts for:
# flask
# anaconda==2020.11 -> flask==1.1.2=py_0

# %%
import geopandas as gpd
from shapely.geometry import Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-19515517d005> in <module>
# ----> 1 import geopandas as gpd
#       2 from shapely.geometry import Polygon
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
points  = [-87.606708,41.816814 -87.606712,41.817080 -87.606717,41.817291 -87.606721,41.817507 -87.606727,41.817688 -87.606728,41.817733 -87.606730,41.817801 -87.606735,41.817944 -87.606743,41.818152 -87.606745,41.818310 -87.606747,41.818439 -87.606750,41.818618 -87.606753,41.818825 -87.606753,41.819040 -87.606753,41.819079 -87.606760,41.819345 -87.606767,41.819477 -87.606772,41.819572 -87.606772,41.819572 -87.606799,41.820071 -87.606804,41.820269 -87.606806,41.820382 -87.606809,41.820487 -87.606820,41.820956 -87.606823,41.821087 -87.606833,41.821503 -87.606845,41.822012 -87.606847,41.822127 -87.606853,41.822425 -87.606855,41.822729 -87.606859,41.823166 -87.606437,41.823306 -87.606873,41.823965 -87.606880,41.823963 -87.606916,41.823960 -87.607029,41.823958 -87.607327,41.823949 -87.608338,41.823937 -87.609587,41.823923 -87.609841,41.823921 -87.612136,41.823897 -87.612624,41.823891 -87.613076,41.823885 -87.614364,41.823869 -87.615148,41.823859 -87.615475,41.823855 -87.616109,41.823848 -87.616732,41.823838 -87.616997,41.823834 -87.617259,41.823830 -87.617710,41.823823 -87.617950,41.823820 -87.618214,41.823817 -87.618551,41.823813 -87.618862,41.823809 -87.619178,41.823805 -87.619988,41.823795 -87.620395,41.823790 -87.620953,41.823783 -87.621602,41.823775 -87.622230,41.823767 -87.622346,41.823766 -87.622408,41.823765 -87.623147,41.823756 -87.624268,41.823742 -87.624